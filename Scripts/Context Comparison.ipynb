# %% [markdown]
# # Imports

# %%
#Script to extract important topics from content
#originally written by: vipul-sharma20
#modifications made by: jadekhiev

# imports
import os
import sys
from pathlib import Path

# imports required utility functions
import string
from collections import Counter

# Data packages
import math
import pandas as pd
import numpy as np

#Operation
import operator

#Natural Language Processing Packages
import re
import nltk
from nltk import tokenize
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
nltk.download('brown')
from nltk.corpus import brown

import spacy
nlp = spacy.load('en') #spacy PoS tagger
# python -m spacy download en
#Progress bar
from tqdm import tqdm
# Out:
# [nltk_data] Downloading package punkt to /Users/jadekhiev/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package brown to /Users/jadekhiev/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %% [markdown]
# # Shared Code

# %%
# Import articles
def importData(filename):
    """
    Import data into df
    """
    #Import Labelled Data
    DATA_DIR = "Data"
    thispath = Path().absolute()
    ARTICLES = os.path.join(DATA_DIR, filename)
    
    df = pd.read_excel(ARTICLES)

    try:
        df.head()
    except:
        pass
    
    return df

# %%
articleDB = importData("test_articles.xlsx")

# %% [markdown]
# # CE V1

# %%
# PoS Tagger and CFG Definitions
# train tagger with browns news corpus
train = brown.tagged_sents(categories='news')

# custom regex tagging
regex_tag = nltk.RegexpTagger([
     #(r'[$][0-9]+\s[MmBbTt]\S+','DV'), #dollar value 
     (r'^[-\:]?[0-9]+(.[0-9]+)?$', 'CD'),
     (r'.*able$', 'JJ'),
     (r'^[A-Z].*$', 'NNP'),
     (r'.*ly$', 'RB'),
     (r'.*s$', 'NNS'),
     (r'.*ing$', 'VBG'),
     (r'.*ed$', 'VBD'),
     (r'.[\/\/]\S+', 'URL'), #URL / useless
     (r'.*', 'NN')
])

unigram_tag = nltk.UnigramTagger(train, backoff=regex_tag)
bigram_tag = nltk.BigramTagger(train, backoff=unigram_tag)
trigram_tag = nltk.TrigramTagger(train, backoff=bigram_tag)

# PoS Browns Corpus Tagging: https://en.wikipedia.org/wiki/Brown_Corpus
# custom defined Context Free Grammar (CFG) by vipul
cfg = dict()
cfg['NNP+NNP'] = 'NNP'
cfg['NN+NN'] = 'NNI'
cfg['NNP+NNI'] = 'NNI'
cfg['NNI+NN'] = 'NNI'
cfg['NNI+NNI'] = 'NNI'
cfg['NNI+NNP'] = 'NNI'
cfg['JJ+JJ'] = 'JJ'
cfg['JJ+NN'] = 'NNI'
cfg['CD+CD'] = 'CD'
cfg['NPI+NNP'] = 'NNP' # this is specific for collecting terms with the word deal
cfg['NNI+RP'] = 'NNI' # collects terms like "heats up" -- RP = adverb particle
cfg['RB+NN'] = 'NNP'# combination for monetary movement e.g. quarterly[RB] profit[NN] fell [VBD] -- RB = adverb
cfg['NNP+VBD'] = 'VPI' #VBP = a verb phrase
cfg['MD+VB'] = 'VPI' # collects terms like "will lose" (verb phrase incomplete)
cfg['MD+NN'] = 'VPI' # collects terms like "will soar" (verb phrase incomplete)
cfg['VPI+NN'] = 'VP' # collects terms like "will lose ground"
cfg['NNI+VP'] = 'VP' # collects terms like "index will soar"
cfg['NN+VPI'] = 'VP' # collects terms like "index will soar"
cfg['NNP+VPI'] = 'VP' # collects terms like "index will soar"
cfg['VPI+TO'] = 'VPI' # collect past participle verbs with to e.g. pledged to
cfg['VBN+TO'] = 'VBN' # collect past participle verbs with to e.g. pledged to
cfg['VBN+NN'] = 'VP' # collects terms like "pledged to adapt"

# Utility functions for context extraction
def getWords(sentence):
    stopwords = [
        # dates/times
        "january", "february", "march", "april", "may", "june", "july", "august", "september", "october"
        , "november", "december", "jan", "feb","mar", "apr", "jun", "jul", "aug", "oct", "nov", "dec"
        , "monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday", "morning","evening"
        ,"today","pm","am","daily"
        # specific article terms that are useless
        , "read", "file", "'s","'t", "photo", "inc", "corp", "group", "inc", "corp", "source"
        , "bloomberg", "cnbc","cnbcs", "cnn", "reuters","bbc", "published", "broadcast","msnbc","ap"
        ,"said","nbcuniversal","newsletterupgrade","nbc", "news",'url',"cbc"
        # other useless terms
        "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself"
        , "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its"
        , "itself", "they", "them", "their", "theirs","themselves", "what", "which", "who", "whom"
        , "this", "that", "these", "those", "theyve", "theyre", "theres", "heres", "didnt", "wouldn"
        , "couldn", "didn","are","is", "was","will", "have", "be", "such"
    ]
    words = word_tokenize(sentence)
    
    words = [word for word in words if len(word)>1 and word.lower() not in stopwords] 
    return words

def countWords(wordList):
    return dict(Counter(wordList))

def get_info(content):
    words = getWords(content)
    temp_tags = trigram_tag.tag(words)
    tags = re_tag(temp_tags)
    normalized = True
    while normalized:
        normalized = False
        #print("len tag: ", len(tags))
        #pp.pprint(DictGroupBy(tags))
        for i in range(0, len(tags) - 1):
            #print("i: ", i)
            tagged1 = tags[i]
            if i+1 >= len(tags) - 1:
                break
            tagged2 = tags[i+1]

            # when word = deal and next word is tagged IN (with, for, etc.) 
            if tagged1[0]=='deal' and tagged2[1]=='IN':
                tags.pop(i)
                tags.pop(i)
                re_tagged = tagged1[0] + ' ' + tagged2[0]
                pos='NPI'
                tags.insert(i, (re_tagged, pos))
                normalized = True

            else: 
                key = tagged1[1] + '+' + tagged2[1]
                pos = cfg.get(key)       
                if pos:
                    tags.pop(i)
                    tags.pop(i)
                    re_tagged = tagged1[0] + ' ' + tagged2[0]
                    tags.insert(i, (re_tagged, pos))
                    normalized = True

    final_context = []
    for tag in tags:
        if tag[1] == 'NNP' or tag[1] == 'NNI' or tag[1] == 'VP':
            final_context.append(tag[0])
    
    return final_context


def re_tag(tagged):
    new_tagged = []
    for tag in tagged:
        if tag[1] == 'NP' or tag[1] == 'NP-TL':
            new_tagged.append((tag[0], 'NNP'))
        elif tag[1][-3:] == '-TL':
            new_tagged.append((tag[0], tag[1][:-3]))
        elif tag[1][-1:] == 'S':
            new_tagged.append((tag[0], tag[1][:-1]))
        else:
            new_tagged.append((tag[0], tag[1]))
    return new_tagged

# extract all unigrams based on all words pulled from context extraction
def unigramBreakdown(fullContext):
    # to be used as frequency count
    stopwords = ["myself", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "him", "his", "himself", "she", "her", "hers", "herself", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "are", "was", "were", "been", "being", "have", "has", "had", "having", "does", "did", "doing",  "the", "and", "but", "if", "or", "because", "until", "while", "for", "with", "about", "into", "through", "during", "before", "after", "from", "down", "out", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "nor", "not", "only", "own", "same", "than", "too", "very", "can", "will", "just", "don", "should", "now", "past", "year", "month", "day"]   
    
    # separates each word for each article => list of list
    articleUnigrams = []
    for term in fullContext:
        articleUnigrams.extend(term.split())
    
    # remove stop words and punctuation
    translator = str.maketrans('', '', string.punctuation)
    unigrams = [term.lower().translate(translator) for term in articleUnigrams if term.lower() not in stopwords and len(term)>2]
    # count frequency of terms
    # unigrams = countWords(unigrams)
    
    return unigrams

# extracts unigrams AND bigrams pulled by context extraction
def bigramBreakdown(fullContext):
    bigrams = []
    
    # remove stop words and punctuation
    translator = str.maketrans('', '', string.punctuation)
    bigrams.extend([term.lower().translate(translator) for term in fullContext if len(term.split()) < 3])
    
    return bigrams

# did this because I couldn't good way to write the switcher to switch to a non-function
def ngramDummy(fullContext):
    stopwords = [
    # dates/times
      "january", "february", "march", "april", "may", "june", "july", "august", "september", "october"
    , "november", "december", "jan", "feb","mar", "apr", "jun", "jul", "aug", "oct", "nov", "dec"
    , "jan.", "feb.","mar.", "apr.", "jun.", "jul.", "aug.", "oct.", "nov.", "dec."
    , "monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday", "morning","evening"
    , "today","pm","am","daily","day", "year"
    # specific article terms that are useless
    , "read", "file", "'s","'t", "photo", "inc", "corp", "group", "inc", "corp", "source"
    , "bloomberg", "cnbc","cnbcs", "cnn", "reuters","bbc", "published", "broadcast","msnbc","ap"
    , "said","nbcuniversal","newsletterupgrade","nbc", "news",'url', "more information","cbc"
    , 'business insider', 'new york times', "wall street journal"
    # other useless terms
    , "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself"
    , "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its"
    , "itself", "they", "them", "their", "theirs","themselves", "what", "which", "who", "whom"
    , "this", "that", "these", "those", "theyve", "theyre", "theres", "heres", "didnt", "wouldn"
    , "couldn", "didn","are","is", "was","will", "have", "be", "were"
    , "company", "people", "president", "others", "times", "percent","number", "companies", "business"
    , "world", "state", "order","talk",'team', 'brands', 'program'
    , 'family', 'everyone', 'per', 'house', 'case', 'someone', 'something', 'anyone',"person"
    , "co.", "co", "inc.", "inc", ".com", "com", "report", "things", "thing", "job", "member", "members"
    , "staying", "possibility","part", "none","showing", "one"
    , "us", "u.s.", "united states", "america", "united states of america", "usa", "states"
    ]
    ngrams = []
    # remove punctuation and translate all terms into lowercse
    # translator = str.maketrans('', '', string.punctuation)
    #bigrams.extend([term.lower().translate(translator) for term in fullContext if len(term.split()) < 3 and term.lower not in stopwords])
    ngrams.extend([term.lower() for term in fullContext if term.lower() not in stopwords])
    
    return ngrams
# PMI For Tag Ranking
# return binary representation of article in terms of all keyphrases pulled
def dfTransform(df, term_column):
    # df is the article df ;
    keyterms = []
    for article in df[term_column].values:
        keyterms.extend([word.lstrip() for word in (article.split(','))])
    keyterms = set(keyterms) # deduplicate terms by casting as set
    
    # for each article and each keyword: give 1 if keyword in article and 0 if not
    encodedArticle = []
    for i in tqdm(df.index):
        articleTerms = ([word.lstrip() for word in (df[term_column].iloc[i].split(','))])
        encodedArticle.append([1 if word in articleTerms else 0 for word in keyterms])
    
    # set up dataframe
    binEncDf = pd.DataFrame(encodedArticle)
    # use keywords as columns
    binEncDf.columns = keyterms
    # keep article_id and prediction from original table
    df = df.rename(columns={'prediction': 'mkt_moving'}) # changed it from prediction because that was also a keyterm
    # join prediction with encoding
    binEncDf = df[['mkt_moving']].join(binEncDf)
    
    return binEncDf

# Simple example of getting pairwise mutual information of a term
def pmiCal(df, x, label_column='mkt_moving'):
    pmilist=[]
    for i in [0,1]:
        for j in [0,1]:
            px = sum(df[label_column]==i)/len(df)
            py = sum(df[x]==j)/len(df)
            pxy = len(df[(df[label_column]==i) & (df[x]==j)])/len(df)
            if pxy==0:#Log 0 cannot happen
                pmi = math.log((pxy+0.0001)/(px*py+0.0001))
            else:
                pmi = math.log(pxy/(px*py+0.0001))
            pmilist.append([i]+[j]+[px]+[py]+[pxy]+[pmi])
    pmiDf = pd.DataFrame(pmilist)
    pmiDf.columns = ['x','y','px','py','pxy','pmi']
    
    return pmiDf

def pmiIndivCal(df,x,gt, label_column='mkt_moving'):
    px = sum(df[label_column]==gt)/len(df)
    py = sum(df[x]==1)/len(df)
    pxy = len(df[(df[label_column]==gt) & (df[x]==1)])/len(df)
    if pxy==0:#Log 0 cannot happen
        pmi = math.log((pxy+0.0001)/(px*py+0.0001))
    else:
        pmi = math.log(pxy/(px*py))
    
    return pmi

# calculate all the pmi for all tags across all articles and store top 5 tags for each article in df
def pmiForAllCal(artDf, binaryEncDf, term_column, label_column='mkt_moving'): 
    
    for i in tqdm(artDf.index): # for all articles
        terms = set(([word.lstrip() for word in (artDf[term_column].iloc[i].split(','))]))
        pmiposlist = []
        pmineglist = []

        for word in terms:
            #pmilist.append([word]+[pmiCal(df,word)])
            pmiposlist.append([word]+[pmiIndivCal(binaryEncDf,word,1,label_column)])
            pmineglist.append([word]+[pmiIndivCal(binaryEncDf,word,0,label_column)])
        
        #pmiDf = pd.DataFrame(pmilist)
        pmiposlist = pd.DataFrame(pmiposlist)
        pmineglist = pd.DataFrame(pmineglist)
        pmiposlist.columns = ['word','pmi']
        pmineglist.columns = ['word','pmi']
        artDf.at[i,'negPMI'] = (',').join(word for word in pmineglist.sort_values(by='pmi', ascending=True).head(5)['word'])
        artDf.at[i,'posPMI'] = (',').join(word for word in pmiposlist.sort_values(by='pmi', ascending=False).head(5)['word'])

    return artDf

# Functions to run extraction and rank tags

# Tag ranking using PMI
def calculatePMI(artDf, termType):
    # use PMI to calculate top 10 terms that should be displayed for each article    
    # get binary encoding of articles represented as uni- and bigrams
    binaryEncDf = dfTransform(artDf, termType)
    articleDf_ranked = pmiForAllCal(artDf, binaryEncDf, termType)
    
    return articleDf_ranked, binaryEncDf

# find most popular keyterms mentioned in news
def frequencyCounter(binEncDf):
    binEncDf = binEncDf.drop(['mkt_moving'], axis=1)
    # sum each column of binary encoded articles
    # output should be a dataframe with: word | # of articles mentioning word
    freqDf = binEncDf.sum(axis=0, skipna=True).sort_values(ascending=False).to_frame().reset_index()
    freqDf.columns = ['word','freq_articles']
    
    return freqDf

# %% [markdown]
# ## Run Code

# %%
# Retrieve context
def retrieveContext_V1(articleDB, termType='ngrams'):
    # import classified articles
    articleDf = articleDB
# 14            1  Trump said he wanted more 'highly skilled' imm...
# 15            1  Five approaches to achieving the right asset m...
# 16            0  Thailand passes internet security law decried ...
# 17            0  J.C. Penney Once Again Learns It Has to Listen...
# 18            0  Whitmer prepares 1st budget: 'There are no eas...
# 19            0  Delta has announced limited-time offers for it...
# 20            0  Saudi Aramco faces key test of demand in globa...
# 21            0  Emboldened by Bolsonaro, armed invaders encroa...
# 22            0  Walmart and Affirm are partnering to offer poi...
# 23            0  Quadriga ‘cold wallets’ found to be empty: report
# 24            0  The City of London is finally starting to beli...
# 25            0                 Term Sheet — Thursday, February 28
# 26            0  D.C.-area forecast: Wintry slop today; quite a...
# 27            0  Is ultra-wealth a problem? More and more, the ...
# 28            0  I put Tesla's high-performance Model S and Mod...
# 29            0     Daily Briefing: Back to normal - ECB too late?
# ..          ...                                                ...
# 291           0  US and France accelerate plans for tech tax re...
# 292           0  Senate GOP ultimatum to Trump on emergency - F...
# 293           0  UPDATE 2-French supermarket operator Carrefour...
# 294           0  A Less Than Merry Christmas for Victoria’s Sec...
# 295           0  Things have gotten so bad at Victoria’s Secret...
# 296           0  A month ago, Elon Musk thought Tesla would be ...
# 297           0  Bristol-Myers Squibb has $2.2 billion at stake...
# 298           0  D.C.-area forecast: Dry but still rather cloud...
# 299           0  States Consider Longer School Recess, and the ...
# 300           0  Amazon just opened up ads within its Instacart...
# 301           0  The FTC is challenging fake Amazon reviews (AMZN)
# 302           0  UPDATE 1-Femsa's Mexican Oxxo stores feel sque...
# 303           0  U.S. economic growth slows moderately in fourt...
# 304           0  The Technology 202: Consumers advocates want W...
# 305           0  Amazon could be gearing up to reveal Walmart, ...
# 306           0  A European data privacy office has 15 open inv...
# 307           0  Jumping Bean hops into U.S. online market with...
# 308           0  What’s next for SNC-Lavalin: Five potential sc...
# 309           0  Walmart to make 'every effort' to keep disable...
# 310           0  How to save money on your planned Amazon purch...
# 311           0  Cohen gives who's who of Trump allies, potenti...
# 312           0  Are passengers to blame for poor airline service?
# 313           0  Walmart: Greeter job going away, not disabled ...
# 314           0  Hannity's laughable Trump-Reagan comparison on...
# 315           0                                 Business this week
# 316           0  These major cities have more dollar stores tha...
# 317           0     The difficulties of making online delivery pay
# 318           0  The Big Number That Explains Kraft Heinz’s Big...
# 319           0  Amazon is planning to open new grocery chain, ...
# 320           0  What Retail Workers Say About Technology Poten...
#
#                                            description               source  \
# 0    Being Catholic is one of the most unpopular th...             cbc-news
# 1    Trump criticizes timing of ‘fake hearing’ afte...  the-washington-post
# 2    Google owned video network lost advertisers an...            usa-today
# 3    Plus, 'impressed' Trump slams 'fake' Michael C...             fox-news
# 4    Business schools join forces to develop online...      financial-times
# 5    Even after one of the most storied careers in ...       financial-post
# 6    “Dreyer’s English”, a bestselling book, is rar...        the-economist
# 7    From reparations to Green New Deal, liberal li...             fox-news
# 8    Heritage award winners on P.E.I. share why the...             cbc-news
# 9    Heated rhetoric about armed conflict raises a ...  the-washington-post
# 10   At a moment when the country has never seemed ...  the-washington-post
# 11   The U.S. economy grew 2.6 percent in Q4 and 2....            usa-today
# 12   What’s behind India-Pakistan tensions, why Chi...      financial-times
# 13                                                 NaN                 cnbc
# 14   The Trump administration has been cracking dow...     business-insider
# 15   Peter Hodson: Things like your investment time...       financial-post
# 16   Thailand's military-appointed parliament on Th...              reuters
# 17   J.C. Penney on Thursday reported poor quarterl...              fortune
# 18   LANSING, Mich. (AP) — Gov. Gretchen Whitmer wa...     associated-press
# 19   Personal Finance Insider writes about products...     business-insider
# 20   Crown prince needs the backing of foreigners —...      financial-times
# 21   Ten days after Brazil's right-wing President J...              reuters
# 22   This is an excerpt from a story delivered excl...     business-insider
# 23   Search for $190 million in cryptocurrency unco...       financial-post
# 24   City of London analysts are starting to virtua...     business-insider
# 25                            On deals and dealmakers.              fortune
# 26   Conditions this afternoon and evening range fr...  the-washington-post
# 27   Is ultra-wealth a problem? More and more, the ...             nbc-news
# 28   I've driven the high-performance Tesla Model S...     business-insider
# 29   A Reuters poll of ECB-watchers released this m...              reuters
# ..                                                 ...                  ...
# 291  Finance ministers agree on need for internatio...      financial-times
# 292  Senate GOP ultimatum to Trump on emergency Fox...             fox-news
# 293  France's Carrefour raised its savings goal and...              reuters
# 294  L Brands shares fell as much as 6.9% in early ...              fortune
# 295  The lingerie brand had a terrible Christmas se...       financial-post
# 296  The cheaper Model 3, store closures, and job c...                 cnbc
# 297  Opposition to pharmaceutical company Bristol-M...     business-insider
# 298  Sunday's forecast is tricky as the rain/snow l...  the-washington-post
# 299  Schoolchildren in Middletown, Conn. A recently...   the-new-york-times
# 300  Amazon is expanding its advertising business t...     business-insider
# 301  This is an excerpt from a story delivered excl...     business-insider
# 302  Mexico's ubiquitous Oxxo stores, run by conglo...              reuters
# 303  The U.S. economy slowed less than expected in ...              reuters
# 304  People buy kits to find their ancestors. Law e...  the-washington-post
# 305  Amazon is reportedly planning to launch a new ...     business-insider
# 306  An office that’s responsible for enforcing Eur...             nbc-news
# 307  Local company also headed Canada-wide in the n...             cbc-news
# 308  SNC is likely headed for a court showdown on f...       financial-post
# 309  After more than a week of backlash, Walmart is...                 cnbc
# 310  Chrome extension mostly pushes shoppers to eBa...            usa-today
# 311  NEW YORK (AP) — Michael Cohen gave Congress a ...     associated-press
# 312  Should consumers be blamed for subpar service ...            usa-today
# 313  Greg Foran, president and CEO of Walmart's U.S...             nbc-news
# 314  Hours after the Hanoi Summit melted down, the ...                  cnn
# 315  Donald Trump lifted a deadline of March 1st fo...        the-economist
# 316  Dollar stores often target poor, rural communi...     business-insider
# 317  Grocers are eager to fulfil customer orders bu...      financial-times
# 318  Kraft Heinz stock is down by two-thirds over t...              fortune
# 319  Amazon, which shook the grocery industry when ...            usa-today
# 320  A report by The Fair Workweek Initiative, The ...              fortune
#
#                      date                                            content  \
# 0    2019-03-03T12:00:00Z   abuse summit took place rome address global p...
# 1    2019-02-28T14:06:39Z   big idea cutting short summit with north kore...
# 2    2019-03-02T14:15:29Z   network receives hours new content every minu...
# 3    2019-02-28T10:06:42Z  trump summit fell north demanded full removal ...
# 4    2019-03-03T20:01:00Z  teamwork core element learning mba courses bus...
# 306  Feb. 28, 2019, 12:00 AM GMT An office thats re...
# 307  A locally owned coffee company is now moving s...
# 308  While the political drama that unfolded in Ott...
# 309  After more than a week of backlash, Walmart is...
# 310  A Canon printer was $7 less on eBay, a Sony RX...
# 311  NEW YORK (AP) Michael Cohen gave Congress a wh...
# 312  Why are airline seats the lone products on the...
# 313  Walmart endured more than a week's worth of ba...
# 314   (CNN)Hours after the Hanoi Summit between Pre...
# 315  Donald Trump lifted a deadline of March 1st fo...
# 316  Dollar stores have been rooted in small towns ...
# 317  Steve Rowe wasadamant this week that he has al...
# 318  The shares and reputation of Kraft Heinz took ...
# 319  Amazon wants to bring back slower delivery for...
# 320  Two out of three retail workers believe that t...
#
#                                       contentWithStops  \
# 0    In February 2019, an abuse summit took place i...
# 1    THE BIG IDEA: After cutting short his summit w...
# 2    But a network that receives 500 hours of new c...
# 3    Trump said the summit fell through after the N...
# 4    Teamwork is a core element of learning on MBA ...
# 5    Even after one of the most storied careers in ...
# 6    WHY DO PEOPLE buy books on English usage? The ...
# 7    The Democrats' 2020 presidential hopefuls are ...
# 8    Interest in restoring P.E.I.'s historic buildi...
# 9    With the report by special counsel Robert S. M...
# 10   With the report by special counsel Robert Muel...
# 11   Experiential spending is the big winner this h...
# 12   This week hostilities between India and Pakist...
# 13   Mike Bloomberg's closest advisors have been me...
# 14   Even as a little boy growing up in China's Jia...
# 15   Most investors assume that smart stock picking...
# 16   BANGKOK (Reuters) - Thailand’s military-appoin...
# 17   J.C. Penney(jcp)on Thursday reported a dismal ...
# 18   LANSING, Mich. (AP) Gov. Gretchen Whitmer want...
# 19    Barring that, the next best option is to open...
# 20   Saudi Arabia’s state-owned energy company is p...
# 21   CAMPO NOVO DE RONDONIA, Brazil (Reuters) - Ten...
# 22    Walmart is partnering with digital-first fina...
# 23   HALIFAX — The high-profile search for $190 mil...
# 24   Analysts and economists in the City of London ...
# 25   • Mirakl, a Paris-based operator of a SaaS-bas...
# 26   A somewhat subjective rating of the days weath...
# 27   As tax season starts its engines, politicians ...
# 28   Heretical? Yes. The BMW M3 has been among the ...
# 29   LONDON (Reuters) - A Reuters poll of ECB-watch...
# ..                                                 ...
# 291  The US and France have said they want industri...
# 292  Measure has bipartisan support - Roll Call: “S...
# 293  PARIS (Reuters) - France’s Carrefour raised it...
# 294  Things have gotten so bad at Victorias Secret ...
# 295  Things have gotten so bad at Victoria’s Secret...
# 296  How rapidly things change in Silicon Valley. A...
# 297  Opposition to Bristol-Myers Squibb's megadeal ...
# 298  A somewhat subjective rating of the days weath...
# 299  The current discussion around playtime reflect...
# 300  Amazon's move into advertising has been compar...
# 301   The US Federal Trade Commission (FTC) has ann...
# 302  MEXICO CITY, Feb 28 (Reuters) - Mexico’s ubiqu...
# 303  WASHINGTON (Reuters) - The U.S. economy slowed...
# 304  A consumer advocacy group leader says it's tim...
# 305  Amazon's purchase of Whole Foods in 2017 sent ...
# 306  Feb. 28, 2019,   GMT An office thats responsib...
# 307  A locally owned coffee company is now moving s...
# 308  While the political drama that unfolded in Ott...
# 309  After more than a week of backlash, Walmart is...
# 310  A Canon printer was $7 less on eBay, a Sony RX...
# 311  NEW YORK (AP) Michael Cohen gave Congress a wh...
# 312  Why are airline seats the lone products on the...
# 313  Walmart endured more than a week's worth of ba...
# 314   (CNN)Hours after the Hanoi Summit between Pre...
# 315  Donald Trump lifted a deadline of March 1st fo...
# 316  Dollar stores have been rooted in small towns ...
# 317  Steve Rowe wasadamant this week that he has al...
# 318  The shares and reputation of Kraft Heinz took ...
# 319  Amazon wants to bring back slower delivery for...
# 320  Two out of three retail workers believe that t...
#
#                                                   tags  \
# 0    abuse summit, rome, global problem, abuse scan...
# 1    the big idea, short summit, korean, kim jong u...
# 2    new content, non-stop game, tiktok, huge 5.7-m...
# 3    trump, full removal, u.s.-led international sa...
# 4    teamwork core element, mba, business schools, ...
# 5    financial markets bill gross, asperger, autism...
# 6    why do people, english, authoritative advice d...
# 7    democrats', presidential hopefuls, far-left id...
# 8    interest, p.e.i historic buildings, recent her...
# 9    special counsel robert s. mueller iii, complet...
# 10   special counsel robert mueller, complete impea...
# 11   experiential, big winner holiday season, sarah...
# 12   week hostilities, india, pakistan nuclear-arme...
# 13   mike, potential staffers, iowa, hampshire, bil...
# 14   china jiangxi, province leo wang knew, america...
# 15   smart stock, long-term investment success view...
# 16   bangkok thailand military-appointed parliament...
# 17   j.c. penney, dismal set, holiday season number...
# 18   lansing mich. gov gretchen whitmer, education ...
# 19   barring, credit card, new card-member bonus oc...
# 20   energy company, issue debut bond key test, inv...
# 21   campo novo de rondonia brazil ten, brazil, pre...
# 22   walmart, affirm, pos, checkout in-store, walma...
# 23   halifax, high-profile search, quadrigacx, smal...
# 24   london, virtually rule, uk, european union, cr...
# 25   mirakl paris-based, saas-based marketplace pla...
# 26   days weather, sloppy mess, wintry mix midday, ...
# 27   tax season starts engines politicians, tax pro...
# 28   heretical, bmw m3, high-performance cars, eart...
# 29   london, ecb-watchers, current tension, economi...
# ..                                                 ...
# 291  france, global tax reform year, ensure tech co...
# 292  bipartisan support roll call sens susan collin...
# 293  paris france carrefour, raised savings, downsi...
# 294  victorias secret parent company, purse strings...
# 295  victoria secret parent company, purse strings,...
# 296  rapidly things, silicon valley month, electric...
# 297  bristol-myers squibb, celgene, bristol-myers, ...
# 298  days weather, clouds, mostly cloudy highs mid-...
# 299  current discussion around playtime reflects, a...
# 300  amazon, facebook, google, walmart, packaged-go...
# 301  federal trade commission ftc, challenged compa...
# 302  mexico city, mexico, oxxo, femsa, mexicans, ba...
# 303  washington, solid consumer, business spending,...
# 304  consumer advocacy leader, washington, dna, fol...
# 305  amazon, whole, shock waves, grocery industry, ...
# 306  gmt, office thats, european data privacy laws,...
# 307  coffee company, available online, sam, walmart...
# 308  political drama, ottawa past week, justin trud...
# 309  walmart, workers 'd, people greeter, greg fora...
# 310  canon, sony rx10iv, amazon, adorama, n't charg...
# 311  congress, donald trump, business associates, t...
# 312  airline seats, lone products, market consumers...
# 313  bad publicity, job loss, amid fierce backlash ...
# 314  hanoi summit, trump, korean, kim jong un, pres...
# 315  donald trump lifted deadline, china, chinese e...
# 316  dollar stores, small towns, rapid expansion, u...
# 317  steve rowe wasadamant week, believed people, m...
# 318  huge hit, food company, kraft heinz, compared ...
# 319  amazon, prime, once week amazon rattled, groce...
# 320  retail workers, job responsibilities, cutting-...
#
#                                                 negPMI  \
# 0    own seminarian brothers,laws regulations,way p...
# 1    never peaceful,cohens,percent growth,politico,...
# 2    cake,icymi,12-megapixel telephoto lens,usa car...
# 3    clinton,trump presidential campaign,boss racis...
# 4    mba,edtech lab,schools part-own,classroom prog...
# 5    glass eye,restore balance,financial markets bi...
# 6    accidence happen,steven pinker harvard,languag...
# 7    politico,energy strategy,sense could support,h...
# 8    notable brick buildings,city heritage board he...
# 9    never peaceful,bad governance,violence,serious...
# 10   never peaceful,bad governance,serious constitu...
# 11   korea kim jong un,percent growth,healthy consu...
# 12   korea kim jong un,country could step,special d...
# 13   clinton,matt paul,own campaign,exclusive agree...
# 14   mba,trump presidential campaign,consumer techn...
# 15   sector allocation,smart stock,actual returns,5...
# 16   european union,nationwide attacks,often casts,...
# 17   buy,walmart,ceo,sears,department store,penney ...
# 18   tax cuts,democrat,long term,twitter,user fees,...
# 19   upgrade list spots,expensive mainstream airlin...
# 20   crown,riyadh,salman,mohammed,saudi arabia,fide...
# 21   supreme court,ministry,u.s,ethnographer sydney...
# 22   walmart,us retailers integration,klarna spliti...
# 23   india,canada,cotten sudden death,advised depos...
# 24   brexit,european union,london,prime,britain,ins...
# 25   africa,texas,upslope ventures spycloud,recruit...
# 26   washington post,fairfax montgomery,partly clou...
# 27   wealth tax,medicare-for-all,ocasio-cortez,midd...
# 28   core issue,long-range non-performance model,sp...
# 29   retail sales,fed,trump,brexit,asia,india,econo...
# ..                                                 ...
# 291  tech companies,france,facebook,europe,abandone...
# 292  beto o'rourke,o'rourke,deal,presidential elect...
# 293  france,china,europe,convenience stores,gmt,bro...
# 294  wednesdays,intelligence,year progresses,late,j...
# 295  intelligence,vs e-commerce site,french luxury ...
# 296  long term,china,europe,q1,switching,company fo...
# 297  insider,bristol-myers breakup fee,future reven...
# 298  washington post,speedy storm system,wettest ye...
# 299  preset instructions,fame now parents can buy,p...
# 300  facebook,walmart,prime,insider,amazonfresh new...
# 301  n't pay,medical risks,weight loss,fake reviews...
# 302  mexicans,marginal business,dramatically. cost,...
# 303  commerce department,labor market,fed,american ...
# 304  executive director,washington post,trump,white...
# 305  walmart,amazon would launch,analyst edward yru...
# 306  past year,federal trade commission,facebook,tw...
# 307  u.s,canada,walmart,john,newfoundlanders,coffee...
# 308  saudi arabia,canada,prime,diplomatic spat,gove...
# 309  public attention,carolina,facebook,walmart,ceo...
# 310  well,boxed,charmin ultrasoft toilet paper,addi...
# 311  personal lawyer,cohen,abbe lowell,media,sater,...
# 312  forbes,singapore,im,york,washington,travel coa...
# 313  public attention,carolina,facebook,walmart,ceo...
# 314  kim,republican,washington post,michael cohen,h...
# 315  brexit,london,china,online-grocery market,glob...
# 316  insider,arlington,poor neighborhoods leaves re...
# 317  britain,mostly own-label,seal £750m acquisitio...
# 318  big drop,eva bogey meeting,shipment delays,ade...
# 319  los angeles,walmart,prime,non-foods department...
# 320  labor market,walmart,high-quality customer ser...
#
#                                                 posPMI
# 0    own seminarian brothers,leaving,way people,cat...
# 1    pakistani government release,umbilical cord bl...
# 2    cake,tech cake,app musical.ly morphed,reddit,c...
# 3    clinton,davidians,four-star general,boss racis...
# 4    edtech lab,control evident,third-party learnin...
# 5    glass eye,bill gross,own admission rub people,...
# 6    accidence happen,syntax,language columnist,ms ...
# 7    energy strategy,warned socialism,doug jones,de...
# 8    notable brick buildings,heritage properties,pr...
# 9    bad governance,civil war rhetoric,actual civil...
# 10   bad governance,countries,political debate,nati...
# 11   healthy consumer spending,stock markets rally,...
# 12   country could step,pre-emptive missile strike,...
# 13   matt paul,congressional midterm elections,earl...
# 14   consumer technology association,trade associat...
# 15   sector allocation,long-term investment success...
# 16   european union,thailand military government al...
# 17   buy,walmart,ceo,chief merchant,department stor...
# 18   tax cuts,democrat,long term,twitter,increase b...
# 19   upgrade list spots,new card-member bonus occas...
# 20   crown,riyadh,salman,mohammed,saudi arabia,mr h...
# 21   supreme court,ministry,u.s,ethnographer sydney...
# 22   walmart,checkout in-store,us retailers integra...
# 23   india,canada,cotten sudden death,account balan...
# 24   brexit,european union,london,prime,britain,ins...
# 25   africa,texas,upslope ventures spycloud,sales t...
# 26   washington post,steadier,dmv,cold snap,needed ...
# 27   wealth tax,middle class,medicare-for-all,ocasi...
# 28   core issue,fast money can buy,car journalist,l...
# 29   retail sales,fed,trump,brexit,asia,india,econo...
# ..                                                 ...
# 291  tech companies,france,facebook,europe,steven m...
# 292  beto o'rourke,o'rourke,deal,presidential elect...
# 293  france,china,europe,cost savings,brokerage ber...
# 294  wednesdays,intelligence,rough patch isnt,mehas...
# 295  intelligence,victoria secret parent company,av...
# 296  long term,china,europe,press brand,popular ele...
# 297  insider,bristol-myers breakup fee,profitable i...
# 298  washington post,speedy storm system,tomorrow s...
# 299  preset instructions,accomplished artists,perso...
# 300  facebook,walmart,prime,insider,chicago accordi...
# 301  n't pay,medical risks,fake reviews sellers wou...
# 302  major business,gas bill,likely roll out,femsa,...
# 303  commerce department,labor market,american good...
# 304  executive director,washington post,trump,white...
# 305  walmart,new concept,still lot,amazon would lau...
# 306  past year,federal trade commission,facebook,tw...
# 307  u.s,canada,walmart,john,fair trade organic,new...
# 308  saudi arabia,canada,prime,top civil servant,po...
# 309  public attention,carolina,facebook,walmart,ceo...
# 310  well,boxed,nordstrom.com,similar prices,charmi...
# 311  personal lawyer,cohen,sater,media,abbe lowell,...
# 312  forbes,singapore,im,york,washington,travel coa...
# 313  public attention,carolina,facebook,walmart,ceo...
# 314  kim,republican,michael cohen,hanoi,washington ...
# 315  brexit,london,china,online-grocery market,glob...
# 316  insider,popular dollar store chains dollar gen...
# 317  britain,mostly own-label,half-empty need,seal ...
# 318  big drop,eva bogey meeting,recent interview bu...
# 319  los angeles,walmart,prime,rivals appeal,grocer...
# 320  labor market,walmart,jacksonville fla.,high-qu...
#
# [321 rows x 14 columns]

# %% [markdown]
# # CE V2

# %%
#Script to extract important topics from content
# based on code written by: vipul-sharma20
# modifications made by: jadekhiev

# imports
import os
import sys
from pathlib import Path

# imports required utility functions
import string
from collections import Counter

# Data packages
import math
import pandas as pd
import numpy as np

#Operation
import operator

#Natural Language Processing Packages
import re
import spacy
# python -m spacy download en
try:
    nlp = spacy.load('en') #spacy PoS tagger
except:
    import en_core_web_sm
    nlp = en_core_web_sm.load()

#Progress bar
from tqdm import tqdm

# Utility functions for context extraction
def tagWords(article):
    # spacy context extraction
    # this is our spacy tagger 
    taggedArticle = nlp(article)
    taggedTerm = []
    stopwords = [
        # dates/times
          "january", "february", "march", "april", "may", "june", "july", "august", "september", "october"
        , "november", "december", "jan", "feb","mar", "apr", "jun", "jul", "aug", "oct", "nov", "dec"
        , "monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday", "morning","evening"
        ,"today","pm","am","daily" 
        # specific article terms that are useless
        , "read", "file", "n't" "'s","'t", "photo", "inc", "corp", "group", "inc", "corp", "source"
        , "bloomberg", "cnbc","cnbcs", "cnn", "reuters","bbc", "published", "broadcast","msnbc","ap"
        , "said","nbcuniversal","newsletterupgrade","nbc", "news",'url',"cbc","faq"
        # other useless terms
        , "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself"
        , "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its"
        , "itself", "they", "them", "their", "theirs","themselves", "what", "which", "who", "whom"
        , "this", "that", "these", "those", "theyve", "theyre", "theres", "heres", "didnt", "wouldn"
        , "couldn", "didn","are","is", "was", "will", "have", "be", "such","did","put","had"
        , "mr", "mr.", "ms", "ms.","mrs", "mrs."
    ]
    for token in taggedArticle:
        if token.text.lower() not in stopwords:
            if len(token.text)>2:
                taggedTerm.append((token.text,token.pos_,token.dep_))
            else: # collect numbers and symbols (percents, dollar signs, etc.)
                if token.text.isdigit() or token.text == '%': taggedTerm.append((token.text,token.pos_,token.dep_))
    return taggedTerm

def countWords(wordList):
    return dict(Counter(wordList))

def getContextTags(content):
    taggedTerm = tagWords(content)
    normalized = True
    while normalized:
        normalized = False
        for i in range(0, len(taggedTerm) - 1):
            token_1 = taggedTerm[i]
            if i+1 >= len(taggedTerm) - 1:
                break
            token_2 = taggedTerm[i+1]
            # chunk nouns
            if token_1[1] in ('NOUN','PROPN') and token_1[2]=='compound' and token_2[1]!='PUNCT':
                newTerm = taggedTerm[i][0]+" "+taggedTerm[i+1][0]
                pos = taggedTerm[i+1][1]
                dep = taggedTerm[i+1][2]
                taggedTerm.insert(i+2, (newTerm, pos, dep))
                taggedTerm.pop(i) # remove word 1
                taggedTerm.pop(i) # remove word 2
                normalized = True

            # chunk nouns with their adjectives
            elif token_1[1]=='ADJ' and token_2[1] in ('NOUN','PROPN'):
                newTerm = taggedTerm[i][0]+" "+taggedTerm[i+1][0]
                pos = taggedTerm[i+1][1]
                dep = taggedTerm[i+1][2]
                taggedTerm.insert(i+2, (newTerm, pos, dep))
                taggedTerm.pop(i) # remove word 1
                taggedTerm.pop(i) # remove word 2
                normalized = True

            # capture nouns that are composed of verb + noun (e.g. share price)
            elif token_1[1]=='VERB' and token_1[2] in ('ccomp') and token_2[1]=='NOUN':
                if i+2 >= len(taggedTerm) - 1:
                    break
                newTerm = taggedTerm[i][0]+" "+taggedTerm[i+1][0]
                pos = taggedTerm[i+1][1]
                dep = taggedTerm[i+1][2]
                taggedTerm.insert(i+2, (newTerm, pos, dep))
                taggedTerm.pop(i) # remove word 1
                taggedTerm.pop(i) # remove word 2
                normalized = True        

            # chunk hyphenated words
            elif token_1[2] in ('compound','npadvmod','amod','advmod','nmod','intj') and token_2[0]=='-':
                newTerm = taggedTerm[i][0]+taggedTerm[i+1][0]+taggedTerm[i+2][0]
                pos = 'ADJ'
                dep = 'amod'
                taggedTerm.insert(i+3, (newTerm, pos, dep))
                taggedTerm.pop(i) # remove word 1
                taggedTerm.pop(i) # remove word 2
                taggedTerm.pop(i) # remove word 3
                normalized = True

            # chunk numeric terms like money and percents
            elif token_1[1] in ('NUM','SYM','NVAL') and token_1[2] in ('nmod','nummod'):
                if token_1[1]=='NUM' and token_2[1]=='NOUN' and not token_2[0]=='%':
                    newTerm = taggedTerm[i][0]+" "+taggedTerm[i+1][0]
                else:
                    newTerm = taggedTerm[i][0]+taggedTerm[i+1][0]
                pos = 'NVAL' # number val
                dep = taggedTerm[i+1][2]
                taggedTerm.insert(i+2, (newTerm, pos, dep))
                taggedTerm.pop(i) # remove word 1
                taggedTerm.pop(i) # remove word 2
                normalized = True

    highlight_text = []
    noun_phrases = []
    for token in taggedTerm:
        term = token[0]
        pos = token[1]
        dep = token[2]
        if pos in ('NOUN', 'PROPN') and dep not in ('npadvmod','amod','advmod'):
            if not(pos == 'NOUN' and len(term.split())<2):
                highlight_text.append(term)
                noun_phrases.append(term)
        elif pos in ('NVAL'): # highlight number values
            highlight_text.append(term)
    
    return highlight_text, noun_phrases

# extract all unigrams based on all words pulled from context extraction
def unigramBreakdown(fullContext):
    stopwords = [
    # dates/times
      "january", "february", "march", "april", "may", "june", "july", "august", "september", "october"
    , "november", "december", "jan", "feb","mar", "apr", "jun", "jul", "aug", "oct", "nov", "dec"
    , "jan.", "feb.","mar.", "apr.", "jun.", "jul.", "aug.", "oct.", "nov.", "dec."
    , "monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday", "morning","evening"
    , "today","pm","am","daily","day", "year"
    # specific article terms that are useless
    , "read", "file", "'s","'t", "photo", "inc", "corp", "group", "inc", "corp", "source"
    , "bloomberg", "cnbc","cnbcs", "cnn", "reuters","bbc", "published", "broadcast","msnbc","ap"
    , "said","nbcuniversal","newsletterupgrade","nbc", "news",'url', "more information","cbc"
    , 'business insider', 'new york times', "wall street journal"
    # other useless terms
    , "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself"
    , "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its"
    , "itself", "they", "them", "their", "theirs","themselves", "what", "which", "who", "whom"
    , "this", "that", "these", "those", "theyve", "theyre", "theres", "heres", "didnt", "wouldn"
    , "couldn", "didn","are","is", "was","will", "have", "be", "were"
    , "company", "people", "president", "others", "times", "percent","number", "companies", "business"
    , "world", "state", "order","talk",'team', 'brands', 'program'
    , 'family', 'everyone', 'per', 'house', 'case', 'someone', 'something', 'anyone',"person"
    , "co.", "co", "inc.", "inc", ".com", "com", "report", "things", "thing", "job", "member", "members"
    , "staying", "possibility","part", "none","showing", "one"
    , "us", "u.s", "u.s.", "united states", "america", "united states of america", "usa", "states"
    ]
    
    # separates each word for each article => list of list
    articleUnigrams = []
    for term in fullContext:
        articleUnigrams.extend(term.split())
    
    # remove stop words and punctuation
    translator = str.maketrans('', '', string.punctuation)
    unigrams = [term.lower().translate(translator) for term in articleUnigrams if term.lower() not in stopwords and len(term)>2]
    # count frequency of terms
    # unigrams = countWords(unigrams)  
    return unigrams

# extracts unigrams AND bigrams pulled by context extraction
def bigramBreakdown(fullContext):
    stopwords = [
    # dates/times
      "january", "february", "march", "april", "may", "june", "july", "august", "september", "october"
    , "november", "december", "jan", "feb","mar", "apr", "jun", "jul", "aug", "oct", "nov", "dec"
    , "jan.", "feb.","mar.", "apr.", "jun.", "jul.", "aug.", "oct.", "nov.", "dec."
    , "monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday", "morning","evening"
    , "today","pm","am","daily","day", "year"
    # specific article terms that are useless
    , "read", "file", "'s","'t", "photo", "inc", "corp", "group", "inc", "corp", "source"
    , "bloomberg", "cnbc","cnbcs", "cnn", "reuters","bbc", "published", "broadcast","msnbc","ap"
    , "said","nbcuniversal","newsletterupgrade","nbc", "news",'url', "more information","cbc"
    , 'business insider', 'new york times', "wall street journal"
    # other useless terms
    , "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself"
    , "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its"
    , "itself", "they", "them", "their", "theirs","themselves", "what", "which", "who", "whom"
    , "this", "that", "these", "those", "theyve", "theyre", "theres", "heres", "didnt", "wouldn"
    , "couldn", "didn","are","is", "was","will", "have", "be", "were"
    , "company", "people", "president", "others", "times", "percent","number", "companies", "business"
    , "world", "state", "order","talk",'team', 'brands', 'program'
    , 'family', 'everyone', 'per', 'house', 'case', 'someone', 'something', 'anyone',"person"
    , "co.", "co", "inc.", "inc", ".com", "com", "report", "things", "thing", "job", "member", "members"
    , "staying", "possibility","part", "none","showing", "one"
    , "us", "u.s.", "united states", "america", "united states of america", "usa", "states"
    ]
    bigrams = []
    # remove punctuation and translate all terms into lowercse
    translator = str.maketrans('', '', string.punctuation)
    #bigrams.extend([term.lower().translate(translator) for term in fullContext if len(term.split()) < 3 and term.lower not in stopwords])
    bigrams.extend([term.lower() for term in fullContext if len(term.split()) < 3 and term.lower() not in stopwords])
    
    return bigrams

# did this because I couldn't good way to write the switcher to switch to a non-function
def ngramBreakdown(keyterms):
    stopwords = [
    # dates/times
      "january", "february", "march", "april", "may", "june", "july", "august", "september", "october"
    , "november", "december", "jan", "feb","mar", "apr", "jun", "jul", "aug", "oct", "nov", "dec"
    , "jan.", "feb.","mar.", "apr.", "jun.", "jul.", "aug.", "oct.", "nov.", "dec."
    , "monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday", "morning","evening"
    , "today","pm","am","daily","day", "year"
    # specific article terms that are useless
    , "read", "file", "'s","'t", "photo", "inc", "corp", "group", "inc", "corp", "source"
    , "bloomberg", "cnbc","cnbcs", "cnn", "reuters","bbc", "published", "broadcast","msnbc","ap"
    , "said","nbcuniversal","newsletterupgrade","nbc", "news",'url', "more information","cbc"
    , 'business insider', 'new york times', "wall street journal"
    # other useless terms
    , "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself"
    , "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its"
    , "itself", "they", "them", "their", "theirs","themselves", "what", "which", "who", "whom"
    , "this", "that", "these", "those", "theyve", "theyre", "theres", "heres", "didnt", "wouldn"
    , "couldn", "didn","are","is", "was","will", "have", "be", "were"
    , "company", "people", "president", "others", "times", "percent","number", "companies", "business"
    , "world", "state", "order","talk",'team', 'brands', 'program'
    , 'family', 'everyone', 'per', 'house', 'case', 'someone', 'something', 'anyone',"person"
    , "co.", "co", "inc.", "inc", ".com", "com", "report", "things", "thing", "job", "member", "members"
    , "staying", "possibility","part", "none","showing", "one"
    , "us", "u.s.", "united states", "america", "united states of america", "usa", "states"
    ]
    ngrams = []
    # remove punctuation and translate all terms into lowercse
    # translator = str.maketrans('', '', string.punctuation)
    #bigrams.extend([term.lower().translate(translator) for term in fullContext if len(term.split()) < 3 and term.lower not in stopwords])
    ngrams.extend([term.lower() for term in keyterms if term.lower() not in stopwords])
    
    return ngrams

# PMI For Tag Ranking
# return binary representation of article in terms of all keyphrases pulled
def dfTransform(df, term_column):
    # df is the article df ;
    keyterms = []
    for article in df[term_column].values:
        keyterms.extend([word.lstrip() for word in (article.split(','))])
    keyterms = set(keyterms) # deduplicate terms by casting as set
    
    # for each article and each keyword: give 1 if keyword in article and 0 if not
    encodedArticle = []
    for i in tqdm(df.index):
        articleTerms = ([word.lstrip() for word in (df[term_column].iloc[i].split(','))])
        encodedArticle.append([1 if word in articleTerms else 0 for word in keyterms])
    
    # set up dataframe
    binEncDf = pd.DataFrame(encodedArticle)
    # use keywords as columns
    binEncDf.columns = keyterms
    # keep article_id and prediction from original table
    df = df.rename(columns={'prediction': 'mkt_moving'}) # changed it from prediction because that was also a keyterm
    # join prediction with encoding
    binEncDf = df[['mkt_moving']].join(binEncDf)
    
    return binEncDf

# Simple example of getting pairwise mutual information of a term
def pmiCal(df, x, label_column='mkt_moving'):
    pmilist=[]
    for i in [0,1]:
        for j in [0,1]:
            px = sum(df[label_column]==i)/len(df)
            py = sum(df[x]==j)/len(df)
            pxy = len(df[(df[label_column]==i) & (df[x]==j)])/len(df)
            if pxy==0:#Log 0 cannot happen
                pmi = math.log((pxy+0.0001)/(px*py+0.0001))
            else:
                pmi = math.log(pxy/(px*py+0.0001))
            pmilist.append([i]+[j]+[px]+[py]+[pxy]+[pmi])
    pmiDf = pd.DataFrame(pmilist)
    pmiDf.columns = ['x','y','px','py','pxy','pmi']
    
    return pmiDf

def pmiIndivCal(df,x,gt, label_column='mkt_moving'):
    px = sum(df[label_column]==gt)/len(df)
    py = sum(df[x]==1)/len(df)
    pxy = len(df[(df[label_column]==gt) & (df[x]==1)])/len(df)
    if pxy==0:#Log 0 cannot happen
        pmi = math.log((pxy+0.0001)/(px*py+0.0001))
    else:
        pmi = math.log(pxy/(px*py))
    
    return pmi

# calculate all the pmi for all tags across all articles and store top 5 tags for each article in df
def pmiForAllCal(artDf, binaryEncDf, term_column, label_column='mkt_moving'): 
    
    for i in tqdm(artDf.index): # for all articles
        terms = set(([word.lstrip() for word in (artDf[term_column].iloc[i].split(','))]))
        pmineglist = []
        pmiposlist = []
        for word in terms:
            pmineglist.append([word]+[pmiIndivCal(binaryEncDf,word,0,label_column)])
            pmiposlist.append([word]+[pmiIndivCal(binaryEncDf,word,1,label_column)])
        pmineglist = pd.DataFrame(pmineglist)
        pmiposlist = pd.DataFrame(pmiposlist)
        pmineglist.columns = ['word','pmi']
        pmiposlist.columns = ['word','pmi']
        artDf.at[i,'negPMI'] = (',').join(word for word in pmineglist.sort_values(by='pmi', ascending=True).head(5)['word'])
        artDf.at[i,'posPMI'] = (',').join(word for word in pmiposlist.sort_values(by='pmi', ascending=False).head(5)['word'])   
    return artDf

# Functions to run extraction and rank tags

# Tag ranking using PMI
def calculatePMI(artDf, termType):
    # use PMI to calculate top 10 terms that should be displayed for each article    
    # get binary encoding of articles represented as uni- and bigrams
    binaryEncDf = dfTransform(artDf, termType)
    articleDf_ranked = pmiForAllCal(artDf, binaryEncDf, termType)
    
    return articleDf_ranked, binaryEncDf

# find most popular keyterms mentioned in news
def frequencyCounter(binEncDf):
    binEncDf = binEncDf.drop(['mkt_moving'], axis=1)
    # sum each column of binary encoded articles
    # output should be a dataframe with: word | # of articles mentioning word
    freqDf = binEncDf.sum(axis=0, skipna=True).sort_values(ascending=False).to_frame().reset_index()
    freqDf.columns = ['word','freq_articles']
    
    return freqDf

# %% [markdown]
# ## Run Code

# %%
# Retrieve context
def retrieveContext_V2(articleDB, termType='ngrams'):
    # import classified articles
    articleDf = articleDB
    
    breakdown = {
        'ngrams': ngramBreakdown, # store n-grams pulled from context extraction
        'bigrams': bigramBreakdown, # store bigrams and unigrams captured by context extraction
        'unigrams': unigramBreakdown # store unigrams captured by separating all terms pulled by context extraction
        }
    
    for i in tqdm(articleDf.index):
        # get context for articles
        fullContext, keyTerms = getContextTags(articleDf['contentWithStops'].iloc[i])
        articleDf.at[i, 'context'] = ', '.join(fullContext) # highlight these terms within article 
        articleDf.at[i, 'tags'] = ', '.join(breakdown[termType](keyTerms)) # use these as tags as they are limited to noun/noun phrases
    
    # returns article Df with new column for top tags
    articleDf, binaryEncDf = calculatePMI(articleDf, 'tags')
    
    # returns most popular terms mentioned across all articles
    trendingTermsDf = frequencyCounter(binaryEncDf)

    return articleDf, trendingTermsDf

# %%
articleDf_2, trendingTermsDf_2 = retrieveContext_V2(articleDB)
# Out:
# 100%|██████████| 321/321 [01:11<00:00,  4.24it/s]
# 100%|██████████| 321/321 [00:08<00:00, 40.03it/s]
# 100%|██████████| 321/321 [01:40<00:00,  2.97it/s]

# %%
articleDf_2
# Out:
#        nonRel       Rel                                                url  \
# 0    0.225382  0.774618  https://www.cbc.ca/news/canada/manitoba/young-...
# 1    0.234248  0.765752  https://www.washingtonpost.com/news/powerpost/...
# 2    0.283077  0.716923  https://www.usatoday.com/story/tech/talkingtec...
# 3    0.323753  0.676247  https://www.foxnews.com/us/trump-kim-summit-en...
# 4    0.358581  0.641419  https://www.ft.com/content/3befa2d8-1824-11e9-...
# 5    0.393527  0.606473  https://business.financialpost.com/investing/t...
# 300           0  Amazon just opened up ads within its Instacart...
# 301           0  The FTC is challenging fake Amazon reviews (AMZN)
# 302           0  UPDATE 1-Femsa's Mexican Oxxo stores feel sque...
# 303           0  U.S. economic growth slows moderately in fourt...
# 304           0  The Technology 202: Consumers advocates want W...
# 305           0  Amazon could be gearing up to reveal Walmart, ...
# 306           0  A European data privacy office has 15 open inv...
# 307           0  Jumping Bean hops into U.S. online market with...
# 308           0  What’s next for SNC-Lavalin: Five potential sc...
# 309           0  Walmart to make 'every effort' to keep disable...
# 310           0  How to save money on your planned Amazon purch...
# 311           0  Cohen gives who's who of Trump allies, potenti...
# 312           0  Are passengers to blame for poor airline service?
# 313           0  Walmart: Greeter job going away, not disabled ...
# 314           0  Hannity's laughable Trump-Reagan comparison on...
# 315           0                                 Business this week
# 316           0  These major cities have more dollar stores tha...
# 317           0     The difficulties of making online delivery pay
# 318           0  The Big Number That Explains Kraft Heinz’s Big...
# 319           0  Amazon is planning to open new grocery chain, ...
# 320           0  What Retail Workers Say About Technology Poten...
#
#                                            description               source  \
# 0    Being Catholic is one of the most unpopular th...             cbc-news
# 1    Trump criticizes timing of ‘fake hearing’ afte...  the-washington-post
# 2    Google owned video network lost advertisers an...            usa-today
# 3    Plus, 'impressed' Trump slams 'fake' Michael C...             fox-news
# 4    Business schools join forces to develop online...      financial-times
# 5    Even after one of the most storied careers in ...       financial-post
# 6    “Dreyer’s English”, a bestselling book, is rar...        the-economist
# 7    From reparations to Green New Deal, liberal li...             fox-news
# 8    Heritage award winners on P.E.I. share why the...             cbc-news
# 9    Heated rhetoric about armed conflict raises a ...  the-washington-post
# 10   At a moment when the country has never seemed ...  the-washington-post
# 11   The U.S. economy grew 2.6 percent in Q4 and 2....            usa-today
# 12   What’s behind India-Pakistan tensions, why Chi...      financial-times
# 13                                                 NaN                 cnbc
# 14   The Trump administration has been cracking dow...     business-insider
# 15   Peter Hodson: Things like your investment time...       financial-post
# 16   Thailand's military-appointed parliament on Th...              reuters
# 17   J.C. Penney on Thursday reported poor quarterl...              fortune
# 18   LANSING, Mich. (AP) — Gov. Gretchen Whitmer wa...     associated-press
# 19   Personal Finance Insider writes about products...     business-insider
# 20   Crown prince needs the backing of foreigners —...      financial-times
# 21   Ten days after Brazil's right-wing President J...              reuters
# 22   This is an excerpt from a story delivered excl...     business-insider
# 23   Search for $190 million in cryptocurrency unco...       financial-post
# 24   City of London analysts are starting to virtua...     business-insider
# 25                            On deals and dealmakers.              fortune
# 26   Conditions this afternoon and evening range fr...  the-washington-post
# 27   Is ultra-wealth a problem? More and more, the ...             nbc-news
# 28   I've driven the high-performance Tesla Model S...     business-insider
# 29   A Reuters poll of ECB-watchers released this m...              reuters
# ..                                                 ...                  ...
# 291  Finance ministers agree on need for internatio...      financial-times
# 292  Senate GOP ultimatum to Trump on emergency Fox...             fox-news
# 293  France's Carrefour raised its savings goal and...              reuters
# 294  L Brands shares fell as much as 6.9% in early ...              fortune
# 295  The lingerie brand had a terrible Christmas se...       financial-post
# 296  The cheaper Model 3, store closures, and job c...                 cnbc
# 297  Opposition to pharmaceutical company Bristol-M...     business-insider
# 298  Sunday's forecast is tricky as the rain/snow l...  the-washington-post
# 299  Schoolchildren in Middletown, Conn. A recently...   the-new-york-times
# 300  Amazon is expanding its advertising business t...     business-insider
# 301  This is an excerpt from a story delivered excl...     business-insider
# 302  Mexico's ubiquitous Oxxo stores, run by conglo...              reuters
# 303  The U.S. economy slowed less than expected in ...              reuters
# 304  People buy kits to find their ancestors. Law e...  the-washington-post
# 305  Amazon is reportedly planning to launch a new ...     business-insider
# 306  An office that’s responsible for enforcing Eur...             nbc-news
# 307  Local company also headed Canada-wide in the n...             cbc-news
# 308  SNC is likely headed for a court showdown on f...       financial-post
# 309  After more than a week of backlash, Walmart is...                 cnbc
# 310  Chrome extension mostly pushes shoppers to eBa...            usa-today
# 311  NEW YORK (AP) — Michael Cohen gave Congress a ...     associated-press
# 312  Should consumers be blamed for subpar service ...            usa-today
# 313  Greg Foran, president and CEO of Walmart's U.S...             nbc-news
# 314  Hours after the Hanoi Summit melted down, the ...                  cnn
# 315  Donald Trump lifted a deadline of March 1st fo...        the-economist
# 316  Dollar stores often target poor, rural communi...     business-insider
# 317  Grocers are eager to fulfil customer orders bu...      financial-times
# 318  Kraft Heinz stock is down by two-thirds over t...              fortune
# 319  Amazon, which shook the grocery industry when ...            usa-today
# 320  A report by The Fair Workweek Initiative, The ...              fortune
#
#                      date                                            content  \
# 0    2019-03-03T12:00:00Z   abuse summit took place rome address global p...
# 1    2019-02-28T14:06:39Z   big idea cutting short summit with north kore...
# 2    2019-03-02T14:15:29Z   network receives hours new content every minu...
# 3    2019-02-28T10:06:42Z  trump summit fell north demanded full removal ...
# 4    2019-03-03T20:01:00Z  teamwork core element learning mba courses bus...
# 5    2019-03-01T19:46:01Z  even one storied careers financial markets bil...
# 6    2019-02-28T15:55:48Z   people buy books english usage obvious answer...
# 7    2019-03-01T19:16:41Z   democrats presidential hopefuls latching onto...
# 8    2019-03-02T11:00:00Z  interest restoring e s historic buildings rema...
# 9    2019-03-01T12:15:00Z  with report special counsel robert mueller iii...
# 10   2019-03-01T13:37:37Z  with report special counsel robert mueller rep...
# 11   2019-02-28T13:40:26Z  experiential spending big winner holiday seaso...
# 12   2019-03-01T15:51:47Z   week hostilities between india pakistan nucle...
# 13   2019-03-01T22:43:00Z  mike closest advisors meeting with potential s...
# 14   2019-03-02T14:00:00Z  even little boy growing up china jiangxi provi...
# 15   2019-03-01T16:47:44Z   investors assume smart stock picking key long...
# 16   2019-02-28T12:40:31Z  bangkok thailand military appointed parliament...
# 17   2019-02-28T22:30:42Z  j penney jcp reported dismal set holiday seaso...
# 18   2019-03-02T12:13:18Z  lansing mich gov gretchen whitmer wants spend ...
# 19   2019-02-28T20:51:00Z   barring next best option open new credit card...
# 20   2019-03-01T22:19:06Z  saudi arabia state owned energy company prepar...
# 21   2019-03-03T11:13:30Z  campo novo de rondonia brazil ten days brazil ...
# 22   2019-02-28T15:05:00Z   walmart partnering with digital first financi...
# 23   2019-03-01T23:59:47Z  halifax high profile search million missing cr...
# 10   With the report by special counsel Robert Muel...
# 11   Experiential spending is the big winner this h...
# 12   This week hostilities between India and Pakist...
# 13   Mike Bloomberg's closest advisors have been me...
# 14   Even as a little boy growing up in China's Jia...
# 15   Most investors assume that smart stock picking...
# 16   BANGKOK (Reuters) - Thailand’s military-appoin...
# 17   J.C. Penney(jcp)on Thursday reported a dismal ...
# 18   LANSING, Mich. (AP) Gov. Gretchen Whitmer want...
# 19    Barring that, the next best option is to open...
# 20   Saudi Arabia’s state-owned energy company is p...
# 21   CAMPO NOVO DE RONDONIA, Brazil (Reuters) - Ten...
# 22    Walmart is partnering with digital-first fina...
# 23   HALIFAX — The high-profile search for $190 mil...
# 24   Analysts and economists in the City of London ...
# 25   • Mirakl, a Paris-based operator of a SaaS-bas...
# 26   A somewhat subjective rating of the days weath...
# 27   As tax season starts its engines, politicians ...
# 28   Heretical? Yes. The BMW M3 has been among the ...
# 29   LONDON (Reuters) - A Reuters poll of ECB-watch...
# ..                                                 ...
# 291  The US and France have said they want industri...
# 292  Measure has bipartisan support - Roll Call: “S...
# 293  PARIS (Reuters) - France’s Carrefour raised it...
# 294  Things have gotten so bad at Victorias Secret ...
# 295  Things have gotten so bad at Victoria’s Secret...
# 296  How rapidly things change in Silicon Valley. A...
# 297  Opposition to Bristol-Myers Squibb's megadeal ...
# 298  A somewhat subjective rating of the days weath...
# 299  The current discussion around playtime reflect...
# 300  Amazon's move into advertising has been compar...
# 301   The US Federal Trade Commission (FTC) has ann...
# 302  MEXICO CITY, Feb 28 (Reuters) - Mexico’s ubiqu...
# 303  WASHINGTON (Reuters) - The U.S. economy slowed...
# 304  A consumer advocacy group leader says it's tim...
# 305  Amazon's purchase of Whole Foods in 2017 sent ...
# 306  Feb. 28, 2019, 12:00 AM GMT An office thats re...
# 307  A locally owned coffee company is now moving s...
# 308  While the political drama that unfolded in Ott...
# 309  After more than a week of backlash, Walmart is...
# 310  A Canon printer was $7 less on eBay, a Sony RX...
# 311  NEW YORK (AP) Michael Cohen gave Congress a wh...
# 312  Why are airline seats the lone products on the...
# 313  Walmart endured more than a week's worth of ba...
# 314   (CNN)Hours after the Hanoi Summit between Pre...
# 315  Donald Trump lifted a deadline of March 1st fo...
# 316  Dollar stores have been rooted in small towns ...
# 317  Steve Rowe wasadamant this week that he has al...
# 318  The shares and reputation of Kraft Heinz took ...
# 319  Amazon wants to bring back slower delivery for...
# 320  Two out of three retail workers believe that t...
#
#                                       contentWithStops  \
# 0    In February 2019, an abuse summit took place i...
# 1    THE BIG IDEA: After cutting short his summit w...
# 2    But a network that receives 500 hours of new c...
# 3    Trump said the summit fell through after the N...
# 4    Teamwork is a core element of learning on MBA ...
# 5    Even after one of the most storied careers in ...
# 6    WHY DO PEOPLE buy books on English usage? The ...
# 7    The Democrats' 2020 presidential hopefuls are ...
# 8    Interest in restoring P.E.I.'s historic buildi...
# 9    With the report by special counsel Robert S. M...
# 10   With the report by special counsel Robert Muel...
# 11   Experiential spending is the big winner this h...
# 12   This week hostilities between India and Pakist...
# 13   Mike Bloomberg's closest advisors have been me...
# 14   Even as a little boy growing up in China's Jia...
# 15   Most investors assume that smart stock picking...
# 16   BANGKOK (Reuters) - Thailand’s military-appoin...
# 17   J.C. Penney(jcp)on Thursday reported a dismal ...
# 18   LANSING, Mich. (AP) Gov. Gretchen Whitmer want...
# 19    Barring that, the next best option is to open...
# 20   Saudi Arabia’s state-owned energy company is p...
# 21   CAMPO NOVO DE RONDONIA, Brazil (Reuters) - Ten...
# 22    Walmart is partnering with digital-first fina...
# 23   HALIFAX — The high-profile search for $190 mil...
# 24   Analysts and economists in the City of London ...
# 25   • Mirakl, a Paris-based operator of a SaaS-bas...
# 26   A somewhat subjective rating of the days weath...
# 27   As tax season starts its engines, politicians ...
# 28   Heretical? Yes. The BMW M3 has been among the ...
# 29   LONDON (Reuters) - A Reuters poll of ECB-watch...
# ..                                                 ...
# 291  The US and France have said they want industri...
# 292  Measure has bipartisan support - Roll Call: “S...
# 293  PARIS (Reuters) - France’s Carrefour raised it...
# 294  Things have gotten so bad at Victorias Secret ...
# 295  Things have gotten so bad at Victoria’s Secret...
# 296  How rapidly things change in Silicon Valley. A...
# 297  Opposition to Bristol-Myers Squibb's megadeal ...
# 298  A somewhat subjective rating of the days weath...
# 299  The current discussion around playtime reflect...
# 300  Amazon's move into advertising has been compar...
# 301   The US Federal Trade Commission (FTC) has ann...
# 302  MEXICO CITY, Feb 28 (Reuters) - Mexico’s ubiqu...
# 303  WASHINGTON (Reuters) - The U.S. economy slowed...
# 304  A consumer advocacy group leader says it's tim...
# 305  Amazon's purchase of Whole Foods in 2017 sent ...
# 306  Feb. 28, 2019,   GMT An office thats responsib...
# 307  A locally owned coffee company is now moving s...
# 308  While the political drama that unfolded in Ott...
# 309  After more than a week of backlash, Walmart is...
# 310  A Canon printer was $7 less on eBay, a Sony RX...
# 311  NEW YORK (AP) Michael Cohen gave Congress a wh...
# 312  Why are airline seats the lone products on the...
# 313  Walmart endured more than a week's worth of ba...
# 314   (CNN)Hours after the Hanoi Summit between Pre...
# 315  Donald Trump lifted a deadline of March 1st fo...
# 316  Dollar stores have been rooted in small towns ...
# 317  Steve Rowe wasadamant this week that he has al...
# 318  The shares and reputation of Kraft Heinz took ...
# 319  Amazon wants to bring back slower delivery for...
# 320  Two out of three retail workers believe that t...
#
#                                                   tags  \
# 0    rome, global problem, abuse scandals, catholic...
# 1    big idea, short summit, long journey, washingt...
# 2    new content, non stop game, whack mole, tiktok...
# 3    trump, north, full removal, international sanc...
# 4    teamwork, core element, mba courses, business ...
# 5    storied careers, financial markets, bill gross...
# 6    english usage, obvious answer, authoritative a...
# 7    democrats, left ideas, pace months, republican...
# 8    p.e.i., historic buildings, recent heritage aw...
# 9    special counsel robert mueller iii, complete i...
# 10   special counsel robert mueller, complete impea...
# 11   experiential spending, big winner, sarah quinl...
# 12   india, armed neighbours, suicide attack, param...
# 13   mike closest advisors, potential staffers, iow...
# 14   little boy, china, jiangxi province, leo wang,...
# 15   most investors, smart stock picking, long term...
# 16   bangkok, thailand, controversial cybersecurity...
# 17   j.c. penney(jcp)on, dismal set, holiday season...
# 18   lansing, mich., gov. gretchen whitmer, educati...
# 19   barring, next best option, new credit card, ne...
# 20   saudi arabia, energy company, debut bond, key ...
# 21   campo novo rondonia, brazil, brazil, president...
# 22   walmart, digital first financing player affirm...
# 23   halifax, high profile search, missing cryptocu...
# 24   city, london, european union, british politics...
# 25   mirakl, marketplace platform, bain capital, fe...
# 26   subjective rating, days weather, sloppy mess, ...
# 27   tax season, tax proposals, ultra wealthy cross...
# 28   best high performance cars, planet earth, elec...
# 29   london, ecb watchers, current tension, policy ...
# ..                                                 ...
# 291  france, reach deal, global tax reform, tech co...
# 292  bipartisan support roll call, sens, susan coll...
# 293  paris, france, carrefour, savings goal, step p...
# 294  bad victorias secret, parent company, purse st...
# 295  bad victoria, secret, parent company, purse st...
# 296  silicon valley, tesla ceo elon musk, electric ...
# 297  bristol myers squibb, biopharma, celgene, late...
# 298  subjective rating, days weather, cloudy highs,...
# 299  current discussion, creative problem, artifici...
# 300  amazon, facebook, google, walmart, goods brand...
# 301  federal trade commission, ftc, first case, ftc...
# 302  mexico city, ubiquitous oxxo stores, conglomer...
# 303  washington, u.s. economy, fourth quarter, soli...
# 304  consumer advocacy leader, washington lawmakers...
# 305  amazon, whole foods, shock waves, grocery indu...
# 306  european data privacy laws, biggest u.s. tech ...
# 307  coffee company, sam, club, walmart, crazy jump...
# 308  political drama, ottawa, justin trudeau, liber...
# 309  walmart, other roles, disabled workers, greg f...
# 310  canon printer, less ebay, sony rx10iv camera, ...
# 311  york, michael cohen, congress, president donal...
# 312  airline seats, lone products, comparison shopp...
# 313  walmart, bad publicity, disabled workers, job ...
# 314  hanoi summit, president trump, historic parall...
# 315  donald trump, china, chinese exports, substant...
# 316  dollar stores, small towns, rapid expansion, i...
# 317  steve rowe, believed people, marks, spencer, m...
# 318  kraft heinz, huge hit, largest food company, k...
# 319  amazon, slower delivery, prime members, amazon...
# 320  job responsibilities, edge technology, new sur...
#
#                                                 negPMI  \
# 0    pope,hot topic issues,intense impact,abuse sca...
# 1    peaceful transition,trump presidency,first ins...
# 2    high resolution,telephoto lens,whack mole,comi...
# 3    oversight committee,terrible thing,democratic ...
# 4    edtech lab,reach more learners,futurelearn,nor...
# 5    glass eye,second act,ohio native,gross,sympath...
# 6    oliver kamm,obvious answer,american copy edito...
# 7    liberal replacements,impoverished nations,alab...
# 8    brick buildings,charlottetown heritage homes,w...
# 9    first instinct,trump presidency,peaceful trans...
# 10   trump presidency,peaceful transition,first ins...
# 11   experiential spending,qualified workers,warier...
# 12   immediate tensions,german isis fighters,der,mi...
# 13   top talent,best talent,inner circle,granite st...
# 14   top talent,best talent,american jobs,immigrati...
# 15   cfa,actual returns,cheap peter hodson,other as...
# 16         european union,apple,google,facebook,amazon
# 17   walmart,wall street,fourth quarter,j.c. penney...
# 18   tax cuts,republicans,democrats,twitter,more tr...
# 19   central america,available upgrades,delta one,m...
# 20   jamal khashoggi,khashoggi,crown prince mohamme...
# 21   supreme court,amazon,ethnographer sydney possu...
# 22   walmart,digital only competitors,major private...
# 23   india,canada,amazon,beleaguered quadrigacx tra...
# 24           brexit,city,european union,london,britain
# 25   africa,new york,same day hotel booking app,fig...
# 26           district,next week,twitter,facebook,highs
# 27   middle class,mass,american dream,n.y.,ocasio c...
# 28   german engineering,more ideas,model,insane aut...
# 29   trade deal,donald trump,president trump,trump,fed
# ..                                                 ...
# 291     mnuchin,tech companies,reach deal,france,apple
# 292  hard line,beto,south carolina,congressional re...
# 293                 china,france,britain,europe,amazon
# 294  north america,wall street,high end lingerie,co...
# 295  north america,wall street,high end lingerie,me...
# 296  fourth quarters,much money,silicon valley,thir...
# 297  index funds,last year,right move,wellington ma...
# 298       next week,twitter,facebook,highs,super gusty
# 299  california,university,amazon,preset instructio...
# 300        first time,walmart,google,new york,facebook
# 301  verge,ftc,federal trade commission,amazon,5-st...
# 302  family members,fourth quarter,amazon,favorable...
# 303  labor market,trump administration,americans,ta...
# 304  future,fbi,customs enforcement,technology,amer...
# 305                  walmart,amazon,grocery,kroger,ups
# 306  past year,washington post,federal trade commis...
# 307           canada,walmart,u.s,coffee company,ledrew
# 308  recent weeks,saudi arabia,canada,worse time,cl...
# 309  public attention,pennsylvania,walmart,many sto...
# 310  amazon,nordstrom.com,canon printer,less ebay,s...
# 311  presidential campaign,house intelligence commi...
# 312        ill,forbes,american,department,recent years
# 313  public attention,pennsylvania,walmart,holly ca...
# 314     north korea,secretary,hanoi,second meeting,kim
# 315  climate change,donald trump,brexit,americas,china
# 316  richmond,highest number,virginia,washington,he...
# 317  chief executive,greater volumes,ladd,closer cu...
# 318  big drop,wall street,last year,bennett stewart...
# 319  walmart,amazon,more laboratory,biggest grocery...
# 320  labor market,center,amazon,potential opportuni...
#
#                                                 posPMI  \
# 0    pope,catholicism,closest friends,intense impac...
# 1    north korean prison,british political class,re...
# 2    high resolution,new v50 thinq,cake,coming mont...
# 3    food policies,tobacco,todd starnes show,first ...
# 4    edtech lab,online products,online teaching too...
# 5    glass eye,howard marks,surl files,budget defic...
# 6    oliver kamm,same recent years,american copy ed...
# 7    presidential field,green dream,government plan...
# 8    brick buildings,hillsborough,water street,isla...
# 9    bad governance,republican vice,moderate versio...
# 10   bad governance,controversial issues,moderate v...
# 11   experiential spending,fed policymakers,rate cu...
# 12   immediate tensions,amy kazmin,german isis figh...
# 13   former mayor,prospective staff members,midterm...
# 14   american jobs,apprentice,hard kerr,immigration...
# 15   cfa,asset movements,smart stock picking,actual...
# 16   european union,apple,google,facebook,governmen...
# 17   walmart,wall street,fourth quarter,penney ceo,...
# 18   tax cuts,republicans,democrats,twitter,union a...
# 19   central america,available upgrades,first class...
# 20   jamal khashoggi,crown prince mohammed bin salm...
# 21   supreme court,ethnographer sydney possuelo,rur...
# 22   walmart,pos financing programs,digital only co...
# 23   india,canada,beleaguered quadrigacx trading pl...
# 24           brexit,city,european union,london,britain
# 25   africa,new york,same day hotel booking app,unc...
# 26   district,next week,twitter,facebook,meteorolog...
# 27   mass,middle class,american dream,wealth tax,ne...
# 28   german engineering,tired bmw,other car journal...
# 29   trade deal,donald trump,president trump,fed,trump
# ..                                                 ...
# 291     mnuchin,reach deal,tech companies,france,apple
# 292  hard line,border wall,other top democrats,o'ro...
# 293    china,france,britain,europe,general performance
# 294  north america,wall street,early trading,brands...
# 295  north america,wall street,vs’ commerce site,ne...
# 296  fourth quarters,silicon valley,much money,thir...
# 297  index funds,last year,strong need,takeda shire...
# 298        next week,twitter,facebook,cloudy,mild side
# 299  california,university,preset instructions,nati...
# 300        first time,walmart,google,new york,facebook
# 301  verge,ftc,federal trade commission,5-star revi...
# 302  family members,fourth quarter,oxxo stores,four...
# 303  labor market,trump administration,americans,ta...
# 304  future,technology,fbi,customs enforcement,amer...
# 305  walmart,mercatus,industry standard,traditional...
# 306  past year,washington post,federal trade commis...
# 307                 canada,walmart,show,come board,u.s
# 308  recent weeks,saudi arabia,canada,worse time,sn...
# 309  public attention,pennsylvania,walmart,adam cat...
# 310  nordstrom.com,houzz website,echo speakers,cano...
# 311  presidential campaign,house intelligence commi...
# 312        forbes,ill,american,department,recent years
# 313  public attention,pennsylvania,walmart,national...
# 314     hanoi,north korea,secretary,second meeting,kim
# 315  climate change,donald trump,brexit,americas,china
# 316  richmond,highest number,virginia,washington,co...
# 317  chief executive,greater volumes,lower capital,...
# 318  big drop,wall street,last year,bennett stewart...
# 319  walmart,more laboratory,interactive experienti...
# 320  labor market,center,walmart employee,major job...
#
#                                                context
# 0    2019 abuse, Rome, global problem, abuse scanda...
# 1    BIG IDEA, short summit, long journey, Washingt...
# 2    500 hours, new content, non stop game, whack m...
# 3    Trump, North, full removal, international sanc...
# 4    Teamwork, core element, MBA courses, business ...
# 5    storied careers, financial markets, Bill Gross...
# 6    English usage, obvious answer, authoritative a...
# 7    Democrats, 2020presidential, left ideas, pace ...
# 8    P.E.I., historic buildings, recent heritage aw...
# 9    special counsel Robert Mueller III, complete i...
# 10   special counsel Robert Mueller, complete impea...
# 11   Experiential spending, big winner, Sarah Quinl...
# 12   India, armed neighbours, suicide attack, param...
# 13   Mike closest advisors, potential staffers, Iow...
# 14   little boy, China, Jiangxi province, Leo Wang,...
# 15   Most investors, smart stock picking, long term...
# 16   BANGKOK, Thailand, controversial cybersecurity...
# 17   J.C. Penney(jcp)on, dismal set, holiday season...
# 18   LANSING, Mich., Gov. Gretchen Whitmer, educati...
# 19   Barring, next best option, new credit card, ne...
# 20   Saudi Arabia, energy company, debut bond, key ...
# 21   CAMPO NOVO RONDONIA, Brazil, Ten days, Brazil,...
# 22   Walmart, digital first financing player Affirm...
# 23   HALIFAX, high profile search, missing cryptocu...
# 24   City, London, European Union, twocrucial, Brit...
# 25   Mirakl, marketplace platform, Bain Capital, Fe...
# 26   subjective rating, days weather, sloppy mess, ...
# 27   tax season, tax proposals, ultra wealthy cross...
# 28   best high performance cars, planet Earth, four...
# 29   LONDON, ECB watchers, current tension, policy ...
# ..                                                 ...
# 291  France, reach deal, global tax reform, tech co...
# 292  bipartisan support Roll Call, Sens, Susan Coll...
# 293  PARIS, France, Carrefour, savings goal, step p...
# 294  bad Victorias Secret, parent company, purse st...
# 295  bad Victoria, Secret, parent company, purse st...
# 296  Silicon Valley, Tesla CEO Elon Musk, electric ...
# 297  Bristol Myers Squibb, biopharma, Celgene, late...
# 298  subjective rating, days weather, cloudy Highs,...
# 299  current discussion, creative problem, artifici...
# 300  Amazon, Facebook, Google, Walmart, goods brand...
# 301  Federal Trade Commission, FTC, first case, FTC...
# 302  MEXICO CITY, 28Mexico, ubiquitous Oxxo stores,...
# 303  WASHINGTON, U.S. economy, fourth quarter, soli...
# 304  consumer advocacy leader, Washington lawmakers...
# 305  Amazon, Whole Foods, shock waves, grocery indu...
# 306  Feb., 282019GMT, European data privacy laws, b...
# 307  coffee company, Sam, Club, Walmart, crazy Jump...
# 308  political drama, Ottawa, Justin Trudeau, Liber...
# 309  Walmart, other roles, disabled workers, 1,000 ...
# 310  Canon printer, less eBay, Sony RX10IV camera, ...
# 311  YORK, Michael Cohen, Congress, President Donal...
# 312  airline seats, lone products, comparison shopp...
# 313  Walmart, bad publicity, disabled workers, job ...
# 314  Hanoi Summit, President Trump, President, hist...
# 315  Donald Trump, China, Chinese exports, 10%, 25%...
# 316  Dollar stores, small towns, rapid expansion, I...
# 317  Steve Rowe, believed people, Marks, Spencer, M...
# 318  Kraft Heinz, huge hit, largest food company, b...
# 319  Amazon, slower delivery, Prime members, Amazon...
# 320  threeretail, job responsibilities, edge techno...
#
# [321 rows x 15 columns]

# %%
DATA_DIR = "Data"
OUTPUT_DIR = os.path.join(DATA_DIR, "context_tags.xlsx")
writer = pd.ExcelWriter(OUTPUT_DIR)
articleDf[['title', 'description','context','posPMI','negPMI']].to_excel(writer,'v1')
articleDf_2[['title', 'description','context','posPMI','negPMI']].to_excel(writer,'v2')
writer.save()

# %%
# Utility functions for context extraction
def tagTest(article):
    # spacy context extraction
    # this is our spacy tagger 
    taggedArticle = nlp(article)
    taggedTerm = []
    for token in taggedArticle:
        taggedTerm.append((token.text,token.pos_,token.dep_))
    return taggedTerm

# %%
artSamp = 'Things have gotten so bad at Victorias Secret that its parent company is tightening the purse strings, including shuttering dozens of underperforming locations. L Brands Inc., owner of the lingerie chain, announced Wednesday plans to close about 53 Victorias Secrets in North America this year, more than three times the 15 its historically closed down in an average year. Victorias Secret square footage in North America will drop by about 3%, it said, even as it continues to grow the footprint of its more successful Bath & Body Works chain. L Brands shares fell as much as 6.9% in early trading on Thursday. The stock had gained 6.7% this year through Wednesdays close. The rough patch isnt new: Victorias Secret has been under scrutiny for years for failing to keep up with shifting consumer demands, especially involving themes of female empowerment and diversity. But its reticence to change has been made even more pronounced with the emergence of competitors like Rihannas lingerie company Savage X Fenty, American Eagle Outfitters Inc.s Aerie and ThirdLove, which aim to be more inclusive of women of different shapes, sizes, and backgrounds. The road only gets harder from here: Major retailer Target(tgt) announced earlier this week plans to launch three new private-label brands specializing in low-cost underwear and sleepwear. On the back of the tough quarter at Victorias Secret, L Brands @(lb) said it sees total company profit, excluding some items, in a range of $2.20 to $2.60 this year. Thats well below the average estimate from analysts. Late last year, the company announced it would slash its dividend in half, a move Wall Street called surprising but prudent. The outlook illustrates that the lingerie-sales struggle will persist until the retailer finds a way to reconnect with shoppers on price, product and image, Bloomberg Intelligence analysts Poonam Goyal and Morgan Tarrant wrote in a note. Investments in VS e-commerce site and employees crimp margin but are vital to success. To try to breathe new life into the aging brand, the company has cycled through a series of leaders. Sharen Jester Turney, who led the chain for a decade, abruptly retired in 2016. Jan Singer took over later that year, exiting after about two years. John Mehas, formerly president of luxury label Tory Burch, was put in charge of Victorias Secret Lingerie earlier this year. It also hired a new head of the PINK brand last year. One of Mehass first big moves was partnering with a French luxury label to sell high-end lingerie as its new leader looks to expand beyond discounted bras and underwear. The main focus for Mehas and PINK chief Amy Hauk will be on getting closer to our customers and improving our merchandise assortments, the company said, noting that it expects to see gradual improvement as the year progresses. There were some bright spots: Digital was a strong suit in the latest quarter, with comparable sales online rising 8%. And the companywhich discontinued swimwear in 2016is bringing it back online in March. As mentioned earlier, our new CEOs in Lingerie and PINK are most focused on our product assortments, where we believe we have clear opportunities to improve, the company said.'
doc = nlp('The 165-year-old U.S. company’s return to the public market comes at a time when stocks are near all-time highs and the popularity of denim is surging, driven by the resurgence of 1990s styles such as high-waist and pinstriped jeans.')
taggedTerms = tagTest('The 165-year-old U.S. company’s return to the public market comes at a time when stocks are near all-time highs and the popularity of denim is surging, driven by the resurgence of 1990s styles such as high-waist and pinstriped jeans.')

# %%
taggedTerms
# Out:
# [('The', 'DET', 'det'),
#  ('165-year', 'NUM', 'advmod'),
#  ('-', 'PUNCT', 'punct'),
#  ('old', 'ADJ', 'amod'),
#  ('U.S.', 'PROPN', 'compound'),
#  ('company', 'NOUN', 'nsubj'),
#  ('’s', 'PART', 'auxpass'),
#  ('return', 'NOUN', 'nsubj'),
#  ('to', 'ADP', 'prep'),
#  ('the', 'DET', 'det'),
#  ('public', 'ADJ', 'amod'),
#  ('market', 'NOUN', 'pobj'),
#  ('comes', 'VERB', 'ROOT'),
#  ('at', 'ADP', 'prep'),
#  ('a', 'DET', 'det'),
#  ('time', 'NOUN', 'pobj'),
#  ('when', 'ADV', 'advmod'),
#  ('stocks', 'NOUN', 'nsubj'),
#  ('are', 'VERB', 'relcl'),
#  ('near', 'ADP', 'prep'),
#  ('all', 'DET', 'det'),
#  ('-', 'PUNCT', 'punct'),
#  ('time', 'NOUN', 'compound'),
#  ('highs', 'NOUN', 'pobj'),
#  ('and', 'CCONJ', 'cc'),
#  ('the', 'DET', 'det'),
#  ('popularity', 'NOUN', 'nsubj'),
#  ('of', 'ADP', 'prep'),
#  ('denim', 'NOUN', 'pobj'),
#  ('is', 'VERB', 'aux'),
#  ('surging', 'VERB', 'conj'),
#  (',', 'PUNCT', 'punct'),
#  ('driven', 'VERB', 'advcl'),
#  ('by', 'ADP', 'agent'),
#  ('the', 'DET', 'det'),
#  ('resurgence', 'NOUN', 'pobj'),
#  ('of', 'ADP', 'prep'),
#  ('1990s', 'NUM', 'compound'),
#  ('styles', 'NOUN', 'pobj'),
#  ('such', 'ADJ', 'amod'),
#  ('as', 'ADP', 'prep'),
#  ('high', 'ADJ', 'amod'),
#  ('-', 'PUNCT', 'punct'),
#  ('waist', 'NOUN', 'pobj'),
#  ('and', 'CCONJ', 'cc'),
#  ('pinstriped', 'VERB', 'amod'),
#  ('jeans', 'NOUN', 'conj'),
#  ('.', 'PUNCT', 'punct')]

# %%
tagged2 = tagWords('There were some bright spots: Digital was a strong suit in the latest quarter, with comparable sales online rising 8%. ')

# %%
tagged2
# Out:
# [('There', 'ADV', 'expl'),
#  ('were', 'VERB', 'ROOT'),
#  ('some', 'DET', 'det'),
#  ('bright', 'ADJ', 'amod'),
#  ('spots', 'NOUN', 'attr'),
#  ('Digital', 'PROPN', 'nsubj'),
#  ('strong', 'ADJ', 'amod'),
#  ('suit', 'NOUN', 'attr'),
#  ('the', 'DET', 'det'),
#  ('latest', 'ADJ', 'amod'),
#  ('quarter', 'NOUN', 'pobj'),
#  ('with', 'ADP', 'prep'),
#  ('comparable', 'ADJ', 'amod'),
#  ('sales', 'NOUN', 'nsubj'),
#  ('online', 'ADP', 'advmod'),
#  ('rising', 'VERB', 'pcomp'),
#  ('8', 'NUM', 'nummod'),
#  ('%', 'NOUN', 'npadvmod')]

# %%
hl, np = getContextTags('There were some bright spots: Digital was a strong suit in the latest quarter, with comparable sales online rising 8% higher.')

# %%
hl
# Out:
# ['Digital', 'latest quarter', 'comparable sales', '8%']

# %%
#import spacy
from spacy import displacy
displacy.render(doc, style='dep', jupyter=True)
taggedTerms
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="643-0" class="displacy" width="3550" height="574.5" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">There</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">were</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">some</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">bright</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">spots:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Digital</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">strong</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">suit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">latest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">quarter,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">comparable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">sales</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">online</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">rising</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">8%.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-643-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-643-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">expl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-643-0-1" stroke-width="2px" d="M420,439.5 C420,264.5 735.0,264.5 735.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-643-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-643-0-2" stroke-width="2px" d="M595,439.5 C595,352.0 730.0,352.0 730.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-643-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,441.5 L587,429.5 603,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-643-0-3" stroke-width="2px" d="M245,439.5 C245,177.0 740.0,177.0 740.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-643-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,441.5 L748.0,429.5 732.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-643-0-4" stroke-width="2px" d="M945,439.5 C945,352.0 1080.0,352.0 1080.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-643-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,441.5 L937,429.5 953,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-643-0-5" stroke-width="2px" d="M770,439.5 C770,264.5 1085.0,264.5 1085.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <tex
# [('There', 'ADV', 'expl'),
#  ('were', 'VERB', 'ROOT'),
#  ('some', 'DET', 'det'),
#  ('bright', 'ADJ', 'amod'),
#  ('spots', 'NOUN', 'attr'),
#  (':', 'PUNCT', 'punct'),
#  ('Digital', 'PROPN', 'nsubj'),
#  ('was', 'VERB', 'acl'),
#  ('a', 'DET', 'det'),
#  ('strong', 'ADJ', 'amod'),
#  ('suit', 'NOUN', 'attr'),
#  ('in', 'ADP', 'prep'),
#  ('the', 'DET', 'det'),
#  ('latest', 'ADJ', 'amod'),
#  ('quarter', 'NOUN', 'pobj'),
#  (',', 'PUNCT', 'punct'),
#  ('with', 'ADP', 'prep'),
#  ('comparable', 'ADJ', 'amod'),
#  ('sales', 'NOUN', 'nsubj'),
#  ('online', 'ADP', 'advmod'),
#  ('rising', 'VERB', 'pcomp'),
#  ('8', 'NUM', 'nummod'),
#  ('%', 'NOUN', 'npadvmod'),
#  ('.', 'PUNCT', 'punct')]
