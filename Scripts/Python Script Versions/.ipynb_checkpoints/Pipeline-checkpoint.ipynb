# %% [markdown]
# # Pipeline to run all files
# * ~~All scripts currently output Excel files because we were working independently~~
# * ~~<b>We'll be changing this so that each script passes dataframes until the end of the pipeline.</b>~~
# * Our plan is to not store anything (refresh daily) but need to consider how to deal with taking in user feedback

# %%
#Gather Articles
import NewsAPI as news
import os

#delete any old sorted article files
#if os.path.exists("articles.csv"):
#    os.remove("articles.csv")

#inputs in order: set manual date (yes=1/no=0, no = last 24 hours of news), manual start date (leave empty if 0), manual end date (leave empty if 0, companies to pull (6= all 19 companies)
articleDB = news.main(0,"","",6) #output is called 'NewsAPIOutput.xlsx' in Python Scripts > Data folder
# Out:
# Gathering articles on (Gap Inc) OR (Foot Locker) OR (L Brands) OR Macerich OR Kimco OR TJX OR CVS OR (Home Depot) OR (Best Buy) OR (Lowe's) OR Walmart OR (Target's) OR TGT OR Amazon OR Kroger OR Walgreens OR Kohl's OR (Dollar General) OR (Bed Bath and Beyond) OR Safeway from: 2019-02-14T09:35:00 to 2019-02-15T09:35:00
# 262

# %%
#Article Cleaning (must pip install tqdm first (only once) to run)
import dataClean as dc
articleDB = dc.DataClean(articleDB)

# %%
#Feature Selection and Binary Article Encoding
import FeatureEncoding as fe
binaryMatrix = fe.encoding(0, df=articleDB)
# Out:
# Binary Encoding
# 100%|██████████████████████████████████████████████████████████████████████████████| 187/187 [00:00<00:00, 5937.97it/s]

# %%
#Logistic Regression Classifier + Article Ranking, complete final file is called 'results_encoding.xlsx'
import logReg as lr
articleDB = lr.runLogReg(binaryMatrix, articleDB)
# Out:
#                                                title  \
# 0  UPDATE 3-Russian markets flinch at prospect of...
# 1  Ikea woos India's rising consumer class, tappi...
# 2  UPDATE 1-U.S., India seek to boost trade ties ...
# 3  Border security bill limits shackling of pregn...
# 4  ‘Here’s the system; it sucks’: Meet the Hill s...
#
#                                          description
# 0  The threat of new U.S. sanctions rocked Russia...
# 1  HYDERABAD, India (AP) — In Hyderabad's bustlin...
# 2  The United States and India plan to boost bila...
# 3  Congress is not only giving Trump money for a ...
# 4  ‘Here’s the system; it sucks’: Meet the Hill s...

# %%
# This code extracts and ranks "tags" + counts frequency of tag mentions in articles 
"""
Inputs: 
    1) articleDB - uses column 'content'
    2) (optional) - tag type (could be 'ngrams'{unlimited}, 'bigrams'{terms with up to 2 words}, or 'unigrams'{single terms})
        - default is 'bigrams'
        - future work: add in noun phrases, named entities 
Outputs:
    1) articleDB = articleDB with appended columns "tags" and "tags_top_5"
    2) trendingTermsDB = keyterms by # article mentions
"""
import ContextExtraction as ce
articleDB, trendingTermsDB = ce.retrieveContext(articleDB)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Padmanie\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\Padmanie\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# 100%|███████████████████████████████████████████████████████████████████████████████| 187/187 [00:00<00:00, 760.95it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████|
# 36                  fortune  2019-02-13T01:44:54Z
# 37  the-wall-street-journal  2019-02-13T00:06:43Z
#
#                                               content  \
# 0   A 30 acre plot of farmland once owned by Presi...
# 1   Good morning The SNC story is dominating the n...
# 2   Selected editorials from Oregon newspapers The...
# 3   Good morning  Term Sheet readers My colleague ...
# 4   There s a new look among some luxury hotels  a...
# 5   The average American would rather share their ...
# 6   Good morning  David Meyer here  filling in for...
# 7   Anyone who s used a traditional WiFi extender ...
# 8    Bloomberg   Despite a flurry of speculation o...
# 9   New Yorks economic development chief acknowled...
# 10   That was some shenanigans  subterfuge  straig...
# 11  Bill and Melinda Gates Bill Gates Facebook Goo...
# 12  Missing a headliner such a WeWork is worse tha...
# 13  Get breaking news alerts and special reports  ...
# 14  The negative  though  is that the softer rubbe...
# 15  App Store Official Charts for the week ending ...
# 16  fashionPublished 13th February 2019 This fashi...
# 17  Welcome to The National Today newsletter  whic...
# 18  RALEIGH  N C   AP  North Carolina Gov  Roy Coo...
# 19  LITTLE ROCK  Ark   AP  The Arkansas Arts Cente...
# 20  President Donald Trump is likely to sign the b...
# 21  Apple CEO Tim Cook and IBM CEO Ginni Rometty a...
# 22  The sun sets last week on the Mojave National ...
# 23  Mr  Johnson wouldnt rule out a boycott in the ...
# 24  Seaport Global initiated coverage on General M...
# 25  Shifts in the behaviour and make up of key mar...
# 26  Sean Parker  the founding president of Faceboo...
# 27  When Jonathan Roger  the former head of Centri...
# 28  The NBA season continues on Tuesday with what ...
# 29  The company is working on a hiring plan that w...
# 30  Netflix is on a tear div  gt  div group  gt  p...
# 31  NEW DELHI These days  the relationship between...
# 32  SAO PAULO  Reuters    Brazilian environmental ...
# 33  LONDON  Reuters    Sterling briefly spiked hal...
# 34  The potential loss of the Amazon headquarters ...
# 35  I set out to write a column three weeks ago ab...
# 36  As Amazon faces political obstacles in buildin...
# 37  Many conservatives are fond of an old T S  Eli...
#
#                                           origContent  \
# 0   A 30-acre plot of farmland once owned by Presi...
# 1   Good morning,\r\nThe SNC story is dominating t...
# 2   Selected editorials from Oregon newspapers:\r\...
# 3   Good morning, Term Sheet readers.\r\nMy collea...
# 4   There's a new look among some luxury hotels, a...
# 5   The average American would rather share their ...
# 6   Good morning. David Meyer here, filling in for...
# 7   Anyone who's used a traditional WiFi extender ...
# 8   (Bloomberg) --Despite a flurry of speculation ...
# 9   New Yorks economic development chief acknowled...
# 10  “That was some shenanigans, subterfuge, straig...
# 11  Bill and Melinda Gates.\r\nBill Gates/Facebook...
# 12  Missing a headliner such a WeWork is worse tha...
# 13  Get breaking news alerts and special reports. ...
# 14  The negative, though, is that the softer rubbe...
# 15  App Store Official Charts for the week ending ...
# 16  fashionPublished 13th February 2019\r\nThis fa...
# 17  Welcome to The National Today newsletter, whic...
# 18  RALEIGH, N.C. (AP) North Carolina Gov. Roy Coo...
# 19  LITTLE ROCK, Ark. (AP) The Arkansas Arts Cente...
# 20  President Donald Trump is likely to sign the b...
# 21  Apple CEO Tim Cook and IBM CEO Ginni Rometty a...
# 22  The sun sets last week on the Mojave National ...
# 23  Mr. Johnson wouldnt rule out a boycott in the ...
# 24  Seaport Global initiated coverage on General M...
# 25  Shifts in the behaviour and make-up of key mar...
# 26  Sean Parker, the founding president of Faceboo...
# 27  When Jonathan Roger, the former head of Centri...
# 28  The NBA season continues on Tuesday with what ...
# 29  The company is working on a hiring plan that w...
# 30  Netflix is on a tear.\r\ndiv &gt; div.group &g...
# 31  NEW DELHI These days, the relationship between...
# 32  SAO PAULO (Reuters) - Brazilian environmental ...
# 33  LONDON (Reuters) - Sterling briefly spiked hal...
# 34  The potential loss of the Amazon headquarters ...
# 35  I set out to write a column three weeks ago ab...
# 36  As Amazon faces political obstacles in buildin...
# 37  Many conservatives are fond of an old T.S. Eli...
#
#                                                  tags  \
# 0   abraham lincoln, illinois, sold auction, retir...
# 1   presence cabinet, globe, trudeaus, decision re...
# 2   selected, oregon, local governments, bill, com...
# 3   written seed, key players, fact investor, spac...
# 4   new look, used part, room sizes, conscious dec...
# 5   health data, new survey, health data, tech, ro...
# 6   kara swisher, interview newsworthiness, dorsey...
# 7   wifi, wifi, wifi, mesh, eero, automatically sw...
# 8   flurry speculation, involved ground, elizabeth...
# 9   high tech, buffalo, tech company, queens, cuom...
# 10  robbed academy, netflix, got, denzel washingto...
# 11  apple, google search, apple, google, apple, go...
# 12  missing, wework, written seed, key players, fa...
# 13  subscribe, old man, tallahassee, dozens interv...
# 14  likewise, transfers weight, reactions turning,...
# 15  app store, charts, top paid, game, marmalade g...
# 16  guest editor, around theme, rise prominence, u...
# 17  national newsletter, directly inbox, counterfe...
# 18  raleigh, named state, cooper, considered head,...
# 19  month crews, ground center, students museum, a...
# 20  open past, trump, cabinet meeting, bill trick,...
# 21  announcement board, skills gap, jobs board, sk...
# 22  mojave, preserve, death, person need, senates,...
# 23  office boycott, businesses state, confederate,...
# 24  motors, price target, car technology, note aut...
# 25  shifts, violent appreciation, yen shot, dollar...
# 26  sean parker, amazon, amazon, private conversat...
# 27  jonathan roger, set outfit, tumble end, diffic...
# 28  nba, nba, watch celtics, live stream, free con...
# 29  recent polls, wide approval, queens, hispanic,...
# 30  low hit, ago stock, william blair, clients sha...
# 31  india, democracies drawing, lately, set trade,...
# 32  used rubber, chico mendes, environment ministe...
# 33  london sterling, thin market, sentiment curren...
# 34  economic underpinnings, citys, quarter century...
# 35  jeff bezos, amazon, evidence point, sanchezs, ...
# 36  amazon, cities, amazon, amazon, new city, medi...
# 37  conservatives fond, clark, washington, portlan...
#
#                                            tags_top_5
# 0   private ownership,plans,sold plot,part family,...
# 1   snc,denise balkissoon,wilson raybould,reach,de...
# 2   extra dough,even costs,proposed increases,trai...
# 3   met founder,fortune tisch,known sort,expensive...
# 4   factor play,used part,pieces luggage,room size...
# 5   privacy scandals,federal government,health inf...
# 6   twitter,years news,dorsey,bad things,stream wa...
# 7   mesh,automatically switch,eero eero,wifi,autom...
# 8   amazon,involved ground,lusskin,direct indicati...
# 9   tech company,amazon,database deals,incentives ...
# 10  oscars,exasperated indignation,right thing,jor...
# 11          dna,media,amazon,steve jobs,google search
# 12  interesting thats,key players,heard dont,broad...
# 13  dead floor,deleo,fanny pack,made videos,back g...
# 14  reactions turning,application lubricant,likewi...
# 15  app store,associated press,reserved material,t...
# 16  winter,derrick adams,pyer moss,narrative part,...
# 17  snc lavalin,twitter,blockchain systems,smartph...
# 18  reserved material,associated press,cooper beas...
# 19  associated press,reserved material,ground cent...
# 20  trump,open past,final decisions,white house,ve...
# 21  trump,national council,kim reynolds,tennessee,...
# 22    abraham lincoln,lincoln,media,according,twitter
# 23  cost business,office boycott,states part,tax r...
# 24  price target,cost efficiencies,trucks,transact...
# 25  briefly touch,shifts,price traders,depreciatio...
# 26  facebook,amazon,getty images,previous statemen...
# 27  shown appetite,harbour energy,set outfit,consi...
# 28  boston celtics,quickly team,sign,clipper phila...
# 29  amazon,become kind,onetime proponent,new dont,...
# 30  huge issue,performer past,tepper,year end,bull...
# 31            canada,facebook,china,trump,rules visas
# 32  amazon,released wave,paraobepa,chico mendes,us...
# 33  news investors,expected swings,brexit,britain,...
# 34  amazon,quarter century,fortune,milwaukee louis...
# 35           trump,amazon,shaped leaks,consider,posts
# 36   illinois,amazon,chicago,attached bids,carlos gim
# 37  american kids,portland ore,washington,measles ...

# %%
import Recommender as rec
FinalArticles = rec.recommender(temp, articleDB)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6b6edc8c02e9> in <module>()
#       1 import Recommender as rec
# ----> 2 FinalArticles = rec.recommender(temp, articleDB)
#
# NameError: name 'temp' is not defined

# %%
FinalArticles.to_excel("FinalArticles.xlsx")

# %%
def FrontPagee(articleDB, trendingTermsDB):
    # number of top articles
    # todo; change to only 'predicted relevant' articles
    numArts = 10
    
    # get articles
    art = articleDB.iloc[0:numArts][['title','source', 'date']]
    art['tags'] = list(map(lambda x: x.split(','), articleDB.iloc[0:numArts]['tags_top_5']))
        
    # get top terms
    tuples = [tuple(x) for x in trendingTermsDB.values]
    topTerms = tuples[:10]
    
    # output final json
    frontpage = {"topterms":topTerms, "articles":art}
    with open("frontPage.json", "w") as write_file:
        json.dump(frontpage, write_file)

# %%
FrontPage(articleDB, trendingTermsDB)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-2de792ffae5a> in <module>()
# ----> 1 FrontPage(articleDB, trendingTermsDB)
#
# <ipython-input-48-a752508bab78> in FrontPage(articleDB, trendingTermsDB)
#      15     frontpage = {"topterms":topTerms, "articles":art}
#      16     with open("frontPage.json", "w") as write_file:
# ---> 17         json.dump(frontpage, write_file)
#
# NameError: name 'json' is not defined
